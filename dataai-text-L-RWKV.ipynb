# %% [markdown]
# # RWKV

# %% [markdown]
# > 「変わることがなければ成長することもない
# > 成長することがなければ真に生きていない」
# > ビル・ゲイツ

# %% [markdown]
# ## RWKVの概要
#
# OpenAIが開発するChatGPTにおけるGPT4は強力であり、同様のモデルが様々登場しつつあるが、モデル動作に必要な計算資源も膨大であり、簡単に自宅やColabで動作させることはできないが、RWKVはこの問題を解決するのではないかと期待されている
#
# 言語モデルは、LSTMなどRNNベースのモデルが利用されてきたが、Transformerの登場により状況が一変した
# - Transformerにより並列処理が可能となり実行速度が向上した
# - しかしながら、必要となる計算資源が膨大になった

# %% [markdown]
# ## RNNとTransformerの違いを再確認
#
# Recurrent Neural Networks (RNN)とTransformerの違いを再確認する
#
# ある文章があり、その単語のトークン列が$F[0], F[1], ... F[n]$とする
#
# - Transformer
#   - Attention Weightを用いて$F[0] ... F[n-1]$の単語の依存関係から$F[n]$の単語を生成する
#   - 文章全体の状態を保持して学習し、残差接続(residual connection)、Dropout、LayerNormなどを利用することで、層数を増やしても安定して学習を進めることができる
#   - Self-Attentionは離れた位置の依存関係を学習できるが、シーケンス内のすべての要素と他のすべての要素との依存関係を計算するため、計算量とメモリ使用量がシーケンス長(トークン数)の2乗つまり、O(n^2)で大きくなるという欠点がある
#   - 一方で計算を並列化することができるため、計算進度を高めることができる
#
# - RNN
#   - $F[n-1]$の単語から$F[n]$の単語を生成というプロセスを繰り返して学習
#   - 単一状態を保持し、これを繰り返し適用するため、離れた位置ほど単語の依存関係が失われていく
#       - 計算を繰り返すため、勾配爆発や勾配消失を発生ひやすい
#   - メモリと計算量は文章長に対して線形にスケールする
#   - 並列化と拡張性の制限からtransformerと同等の性能を達成することが困難

# %% [markdown]
# # RWKV(Receptance Weighted Key Value)とは?
#
# transformerの効率的な並列学習とRNNの効率的な推論の両方を兼ね備えたモデル
#
# 名前は、利用する4つのパラメータ$R, W, K, V$に由来する

# %% [markdown]
# ## RWKVの特徴
#
# 次のように纏めることができる
#
# - RNNベースのモデルを用いて、推論の高速化と省メモリ化を実現
#   - 推論時のメモリ使用率は最も大きい14Bモデルでも3GB程度
# - 数百億のパラメータまでスケールする(これが限界かどうかは不明であるが、スケール則は有効と思われる)、非Transformerアーキテクチャ
#   - この規模はRNNベースのモデルでは達成できなかった
# - 同一サイズのTransformerと同等の性能を発揮
# - 学習時はTransformerと同様の動作であるため、並列化が容易
# - 文章長が理論上無限となる(学習時の文章長に依存し、実際は1024程度)
# - AttentionではなくRWKVモデルを利用する
#
# RWKVモデルは https://github.com/BlinkDL/ において公開されており、RWKV1からRWKV4までの4つのモデルが存在
#
# ここでは、RWKV2を用いるが、このモデルは推論にRNNモード、学習にTransformerモードを利用する

# %% [markdown]
# ## TransformerとRWKVの違い
#
# 構造の違いを図を用いて表すと次の通り
#
# - RWKVは、特徴的なTime-mixing blockとChannel-mixing blockが存在
# - Transformerと異なり、encoder-decoderモデルではない
# - 全体の構造はTransformerと類似する
#   - Time-mixing blockとmultihead attentionというブロックが同様の配置・連結された構造を持つが中身が異なる
#
# <img src="http://class.west.sd.keio.ac.jp/dataai/text/transformer-rwkv.png" width=700>

# %% [markdown]
# # RWKVの詳細
#
# RWKVを特長づけるブロックとしてTime-mixing blockとChannel-mixing blockがある
#
# RWKVという名称の由来にもなっている4つのパラメータはTime-mixingブロックとChannel-mixingブロックで使用され、次の意味を持つ
# - R:過去の情報の受容度を表現するReceptanceベクトル
# - W:位置の重み減衰ベクトル。訓練可能なモデルパラメータ
# - K:一般的なAttention Mechanismと同様のK(Key)ベクトル
# - V:一般的なAttention Mechanismと同様のV(Value)ベクトル

# %% [markdown]
# ## TransformerからRWKVへ

# %% [markdown]
# ### Transformer
#
# $$Attention(Q,K,V)=softmax(\frac{QK^T}{\sqrt{d_k}})V$$
#
# ここでQ、K、Vはクエリ(Query)、キー(Key)、値(Value)を示し、キーの次元数$d_k$，シーケンス長(トークン数)$N$、次元数$d_v$である
#
# $F[t+1]$の予測に、$F[0]...F[t]$の文章と、現在の単語$x_t$と$F[t]$をそれぞれ比較して文脈全体の依存関係を考慮する
# - 具体的には$Qx_t$と$K(F[0]...F[t])$の全ての単語の内積によりAttention Weightを求め、前の各状態$F[i]$と比較して類似度を求める
#
# すべてのQueryベクトルとKeyベクトルの内積を計算するため、計算量が$n^2$となる

# %% [markdown]
# ### An Attention Free Transformer (AFT)
#
# Self-Attentionの代わりに普通の全結合層(Fully Connected layer)を利用したモデル
# - 計算コストを大幅に削減
# - 条件によって、Transformerと同等またはそれ以上のパフォーマンスを達成
#
# AFTは次のように求めることができる
#
# $$Attn^+(W,K,V)_t=\frac{\sum^t_{i=1}e^{\omega t,i+k_i}v_i}{\sum^t_{i=1}e^{\omega t,i+k_i}}$$
#
# ここで$\omega_{t,i} \in R^{T\times T}$は、学習した関係における位置バイアスを表す
#
# また、厳密ではないがRWKVを数的に表現すると、
#
# $$v_{i+1} = sigmoid(Rx[t])\cdot \sum^t_{i=0}{Attn^+(W,K,V)_t}$$
#
# となるため、一つ先($t+1$番目)の単語を予測する場合は、$t$番目の単語の予測に$sigmoid(R*F[t])$、$t～0$番目の単語の予測に$v_i$と$\omega_{t,i+k_i}$の2つを用いる
#
# - なお、活性化関数は$sigmoid$である必要はないが、$sigmoid$の性能が高いという評価結果がある
#   - この$sigmoid$の項は正規化せずreceptanceと呼ぶ
# - MultiHeadAttentionは存在せず、各単語に$0～t$番目の単語との依存関係を求める必要ない
#   - $e^{\omega t,i+k_i}v_i$の項が依存関係を表現する
#
# この式により、RNNと同様再帰的に適用することで、$t-1$番目から、$t$番目を予測できる
# - 一つ前の$v_{i-1}$に対して$e^\omega$を掛け合わせ、$v_i$に関する項を足し合わせればよい
# - この計算量の増大が、高々$O(n)$として表現できることから、計算コストを削減できる

# %% [markdown]
# ## Time-mixing block

# %% [markdown]
# ### Time-mixing blockの動作内容
#
# RWKVの時刻$t$における各ベクトル・パラメータであるReceptanceベクトル($r_t$)、Key($k_t$)、Value($v_t$)は、次の式で表すことができる
#
# $$r_t=W_r\cdot(\mu_rx_t+(1−\mu_r)x_{t−1}) \\
# k_t=W_k\cdot(\mu_kx_t+(1−\mu_k)x_{t−1}) \\
# v_t=W_v\cdot(\mu_vx_t+(1−\mu_v)x_{t−1})$$
#
# これらの値は時刻$t$での更新割合を制御するパラメータであり、0と1の間の値をとる
# - $\mu_r$​が大きいほど新しい入力$x_t$​の影響が強く、小さいほど過去の状態$x_{t−1}$​の影響が強くなる
#
# $mu_r$倍の新しい入力(x_t)と$1-mu_r$倍の和であることから、新しい入力と過去の状態との間で線形補間を行う式
# - 従って、これを繰り返すことで再帰的に更新できる
#
# これらを使った演算の詳細は次の通りであり、An Attention Free Transformer (AFT）と類似している
#
# $$wk_vt=\frac{\sum_{i=1}^{t−1}e^{−(t−1−i)w+k_i}v_i+e^{u+k_t}v_t}{\sum_{i=1}^{t−1}e^{−(t−1−i)w+k_i}+e^{u+k_t}}$$
# $$o_t=W_o\cdot(\sigma(r_t)\odot wk_vt)$$
#
# $wkv_t$​は、$Attn(Q,K,V)$と同様の役割を担っているが、$Q，K，V$の各要素はスカラーのため計算コストが小さい
#
# - 直感的には、時間$t$が増加するにつれてベクトル$o_t$​は長い履歴に依存することを示しているといえる
# - ターゲットポジション$t$に対して、RWKVは位置間隔$[1, t]$での加重平均とレセプタンス$sigmoid(R)$と乗算している
#   - 与えられたタイムステップ内で乗算され、異なるタイムステップで合計される
# - 標準的なトランスフォーマーは全てのトークンのペア間でアテンションを計算するが、AFTは過去の時間ステップ全てにわたる加算の形でアテンションを計算するため、計算とメモリ利用効率が向上している

# %% [markdown]
# ### 時間減衰率(Time-Weighting)
#
#
# RWKVはAFTに倣い、$\omega_{t,i}$​をチャネルごとの時間減衰ベクトルとして定義している
#
# $$\omega_{t,i} = -t(t-i)\omega$$
#
# このモデルではTime-MixingおよびTime-Weightingというパラメータを導入している
# - Time-Weightingを距離によるAttentionと呼ぶ
#
# Wはヘッド数、block_size(0～現在の時刻)、block_sizeの3次元で構成され、attに$\mathbb{W}$を要素ごとかけた値をdropoutしている
#
# $\mathbb{W}$は比較的小さいパラメータであり、このようなパラメ―タで離れた単語の依存関係を学習可能とする
#
# これは、異なる距離のトークン($W[:, block_size, block_size]$)が現在の単語attに与える影響は異なり、特に文章の後半は長い距離の$\mathbb{W}$を用いる必要があるが、最初は履歴が小さく必要がない
#
# - SelfAttentionはそのような考慮がない
#
# 実際には$\mathbb{W}$は巡回行列でありバイアスを加算する必要があり、Time Weightingの導入によりPositionalEncodingが不要になる

# %% [markdown]
# ### Time-mixing blockの実装
#
# 下記コードの関数`RWKV_TimeMix`の概要は次の通り
# - 時刻$t$における入力の更新割合$µ_r$​はself.time_mixで表される
# - また時刻$t−1$の入力xはnn.ZeroPad2dを用いて表されている
# - これらを用いると入力$x$は、`x = x * self.time_mix + self.time_shift(x) * (1 - self.time_mix)`と実装され、時間的にシフトした部分すなわち過去の情報と、シフトしていない部分すなわち現在の情報を適切な比率で混合した値へと変換している

# %% [markdown]
# ## Channel-mixing block
#
# channel-mixing blockは次の式で表される
#
# $$r_t=W_r\cdot(\mu_rx_t+(1−\mu_r)x_{t−1})$$
# $$k_t=W_k\cdot(\mu_kx_t+(1−\mu_k)x_{t−1})$$
# $$o_t=\sigma(r_t)\odot(W_v\cdot max(k_t,0)^2)$$
#
# Time-mixing blockは異なる時間ステップのトークン間の相互作用を管理するのに対して、Channel-mixing blockは同じ時間ステップ内の異なるチャンネル（または特徴）間の相互作用を管理する
#
# Channel-mixing blockは、全結合層や畳み込み層と同様の働きを持つ
# - $\sigma$はsquared ReLUを使用し、忘却ゲートの役割を果たす
#
# Channel-mixing blockの実装は、Time-mixing blockが理解できれば問題なく理解であろう

# %% [markdown]
# # RWKVの特徴
#
# RWKVは学習時time-parallel mode (時間パラレルモード)が使用され、推論時（デコード時）はtime-sequential mode (時間シーケンシャルモード)が使用される
#
# <img src="http://class.west.sd.keio.ac.jp/dataai/text/rwkv.png" width=500>

# %% [markdown]
# ## 時間パラレルモード
#
# 学習時のモード
#
# 時間パラレルモードは言葉の通り、時刻に関連する演算を並列して行う
#
# Time-mixing blockで説明したように新しい入力$x_t$と過去の状態との間で線形補間を行う
# - 結果として、各タイムステップの計算が他のタイムステップの計算と独立に実行できる
# - RNNとは異なり並列処理が可能

# %% [markdown]
# ## 時間シーケンシャルモード
#
# 推論時のモード
#
# 学習時とは異なり、推論時にはRNNのような順次的なデコーディングを行う
#
# - このときRWKVはRNNと同様の構造を活用して動作する
#   - これを時間シーケンシャルモードと呼ぶ
#   - 各ステップの出力が次のステップの入力として用いられる
#   - RNN同様、は出力トークンを一度に1つずつ生成し、あるトークンの生成は前のすべてのトークンの生成が完了した後に行わる
#
# RWKVはシーケンスの長さに関係なく一定の速度とメモリフットプリントを維持しする
# - 長いシーケンスを効率的に処理できる
# - 一方で、アテンションメカニズムを使用しているため、シーケンスの長さに比例してキャッシュの使用量が増加する
#
# 以上からRWKVではTransfromerでは実現できなかった効率的なデコーディングが可能となる

# %% [markdown]
# # RWKVの学習

# %% [markdown]
# 以下、実際に学習を行うが、学習にGoogle Colaboratory ProでA100を利用した場合でも10時間強程度必要となるため、基本的に放置になる
# - 放置した結果、仮想マシンごと削除されると何も残らないため、ドライブをマウントしてそちらに結果を保存するようにする
# - 無償利用している場合は、少々気を付けて実行すること

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
if not os.path.exists('cuda.tgz'):
  #!wget "https://drive.google.com/uc?export=download&id=10TVle71vI4B7bB-pPYLEaog4ut74sG6q" -O cuda.tgz
  # !wget https://keio.box.com/shared/static/71it8nriiu5h00630chy29x5ns3ucl74 -O cuda.tgz
  # !tar xzf cuda.tgz
if not os.path.exists('enwik8.tgz'):
  #!wget "https://drive.google.com/uc?export=download&id=10TN_ZnQ3G84vhzoR-AiVfekt4SJMKVW5" -O enwik8.tgz
  # !wget https://keio.box.com/shared/static/9lk6sqkf1ol5z0glfmukvjtvs07zzmd0 -O enwik8.tgz
  # !tar xzf enwik8.tgz
# Out:
# --2023-06-18 08:10:22--  https://keio.box.com/shared/static/71it8nriiu5h00630chy29x5ns3ucl74
# Resolving keio.box.com (keio.box.com)... 74.112.186.144
# Connecting to keio.box.com (keio.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/71it8nriiu5h00630chy29x5ns3ucl74 [following]
# --2023-06-18 08:10:22--  https://keio.box.com/public/static/71it8nriiu5h00630chy29x5ns3ucl74
# Reusing existing connection to keio.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://keio.app.box.com/public/static/71it8nriiu5h00630chy29x5ns3ucl74 [following]
# --2023-06-18 08:10:22--  https://keio.app.box.com/public/static/71it8nriiu5h00630chy29x5ns3ucl74
# Resolving keio.app.box.com (keio.app.box.com)... 74.112.186.144
# Connecting to keio.app.box.com (keio.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!hI6jIN9_Z3KsZcJJ4KXIvvLpR3SvU3bOpLlTQbfdvZnkQYxFyoIdvnglls40u1d_gS9aBo2RRjXznUH-AjxAyhfLORieRiLorkmRw8Ms6J7vW7XoTf-PqQ1DJ4QJpuGu0-ajpvEk_eQHqgg6I01znJ79XOP3YsVokCq_s94_lrZPiZeLPVgQVWrSxCq97u5tpc4AfqDxgU4DTCtCpUoZuTeBw8r8_ZF8KUQx-BYXDlYZZVxC70rGRu_BbG3Otjcdx8sHSLH49HmgR9qrgbZYIqPl7mFBzXorWWnLprYe0OLll28OeOHT6-4T4iAmMMAgPAjl6jGkfzqUtzkeO-ZxIcRKPKMy5T2e_1QaC7jnH7MO0XK2KQ_6WdQS1Q_3TdcTjbDne9DDj9LqQyMDKfJ5V52TRV-lvMIHzaJOPrc8crSQk4tiGhJJ3XCSVikZLsWqZ2iEdFklQ8umSB8Be8otUt-mbqUdTfa0FrIOQMfPxotAC-LqPNCga8NfoUwZ3f1kBSl7k_0q_z9RnIeM4FzBFQvNhyLQCBLl4XCDKv0-rqOauIQUyelff1bGvXefqysw5OOvuQxQdMTNhHDbdtNCtge5pjKdn_WOMaNCN-OjwQO-gQj4jyjI7dxHsZnDeAPYPDBk_pTPCaVstSGNtlF16kgl0VpEdqxSNxUZqq7VljMufD-WJFlRSePR7Bvr43BX6g5jwIcw5vb9_iuOMJM6yAyhkDK9xXN4_SHu5nZKcVRnVNIelB-tQaRYSmGumcIshdhailtsCXQ93gNtvgtuDHv2J69YZpTryNVCEfI_pxKno0KseP92Eh77UKlHUPPLUSHcnvab38Jf-Mg8s7KuVUW2MhnHU0XQwnRs977eNnNUc9Q8oRKs2kISbYvTAxACGIaKunGMVcRp_mYnH4jOCHGi1sLk8hVrAs_pvZBIIfAZ4q6yaFuJNW8_Lbai9OY__7KI69fiXw9dydSk-J7SuNMHzzZ2Zbo7rrRc_A_MbHHVQ0taAM-D66zf9lvvvVdh9ZZVT2YPGYpNbldUZQYZCAoULNC9ASB_xLtv4Ft0BviQb8bi6zMQIoKF-5WCq4oDPFsUrR0NAiBPV6hByzWnFrY0m-bistGi9YY-Grf3jyv_ZOtESOvT6QMH-Ki8x82vFaGHyQuPOgTJOU0HG9Qr2MfZMFJyq41HX0S52-fEqCi8Ht7lALV1AOFd-UkDG0RlS4C5B9I-QAdR1o09woxS3K2L6_MYUZd2nN9G5KVbBSdCVLA5WHvdGrqBeGLF2ibBFK4zKuB1tGhl6vHjrQry4fbLMgsGeN3IoTCS7WC-xRCZXgBfX2ZEDx0KmHXAofJNPf-A_lCCV6ainsBP4h4elfi5O_GaSLlmF0sEa4T8fYHwNDSdjYqh/download [following]
# --2023-06-18 08:10:22--  https://public.boxcloud.com/d/1/b1!hI6jIN9_Z3KsZcJJ4KXIvvLpR3SvU3bOpLlTQbfdvZnkQYxFyoIdvnglls40u1d_gS9aBo2RRjXznUH-AjxAyhfLORieRiLorkmRw8Ms6J7vW7XoTf-PqQ1DJ4QJpuGu0-ajpvEk_eQHqgg6I01znJ79XOP3YsVokCq_s94_lrZPiZeLPVgQVWrSxCq97u5tpc4AfqDxgU4DTCtCpUoZuTeBw8r8_ZF8KUQx-BYXDlYZZVxC70rGRu_BbG3Otjcdx8sHSLH49HmgR9qrgbZYIqPl7mFBzXorWWnLprYe0OLll28OeOHT6-4T4iAmMMAgPAjl6jGkfzqUtzkeO-ZxIcRKPKMy5T2e_1QaC7jnH7MO0XK2KQ_6WdQS1Q_3TdcTjbDne9DDj9LqQyMDKfJ5V52TRV-lvMIHzaJOPrc8crSQk4tiGhJJ3XCSVikZLsWqZ2iEdFklQ8umSB8Be8otUt-mbqUdTfa0FrIOQMfPxotAC-LqPNCga8NfoUwZ3f1kBSl7k_0q_z9RnIeM4FzBFQvNhyLQCBLl4XCDKv0-rqOauIQUyelff1bGvXefqysw5OOvuQxQdMTNhHDbdtNCtge5pjKdn_WOMaNCN-OjwQO-gQj4jyjI7dxHsZnDeAPYPDBk_pTPCaVstSGNtlF16kgl0VpEdqxSNxUZqq7VljMufD-WJFlRSePR7Bvr43BX6g5jwIcw5vb9_iuOMJM6yAyhkDK9xXN4_SHu5nZKcVRnVNIelB-tQaRYSmGumcIshdhailtsCXQ93gNtvgtuDHv2J69YZpTryNVCEfI_pxKno0KseP92Eh77UKlHUPPLUSHcnvab38Jf-Mg8s7KuVUW2MhnHU0XQwnRs977eNnNUc9Q8oRKs2kISbYvTAxACGIaKunGMVcRp_mYnH4jOCHGi1sLk8hVrAs_pvZBIIfAZ4q6yaFuJNW8_Lbai9OY__7KI69fiXw9dydSk-J7SuNMHzzZ2Zbo7rrRc_A_MbHHVQ0taAM-D66zf9lvvvVdh9ZZVT2YPGYpNbldUZQYZCAoULNC9ASB_xLtv4Ft0BviQb8bi6zMQIoKF-5WCq4oDPFsUrR0NAiBPV6hByzWnFrY0m-bistGi9YY-Grf3jyv_ZOtESOvT6QMH-Ki8x82vFaGHyQuPOgTJOU0HG9Qr2MfZMFJyq41HX0S52-fEqCi8Ht7lALV1AOFd-UkDG0RlS4C5B9I-QAdR1o09woxS3K2L6_MYUZd2nN9G5KVbBSdCVLA5WHvdGrqBeGLF2ibBFK4zKuB1tGhl6vHjrQry4fbLMgsGeN3IoTCS7WC-xRCZXgBfX2ZEDx0KmHXAofJNPf-A_lCCV6ainsBP4h4elfi5O_GaSLlmF0sEa4T8fYHwNDSdjYqh/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 74.112.186.128
# Connecting to public.boxcloud.com (public.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1490 (1.5K) [application/octet-stream]
# Saving to: ‘cuda.tgz’
#
# cuda.tgz            100%[===================>]   1.46K  --.-KB/s    in 0s
#
# 2023-06-18 08:10:23 (11.7 MB/s) - ‘cuda.tgz’ saved [1490/1490]
#
# --2023-06-18 08:10:23--  https://keio.box.com/shared/static/9lk6sqkf1ol5z0glfmukvjtvs07zzmd0
# Resolving keio.box.com (keio.box.com)... 74.112.186.144
# Connecting to keio.box.com (keio.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9lk6sqkf1ol5z0glfmukvjtvs07zzmd0 [following]
# --2023-06-18 08:10:23--  https://keio.box.com/public/static/9lk6sqkf1ol5z0glfmukvjtvs07zzmd0
# Reusing existing connection to keio.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://keio.app.box.com/public/static/9lk6sqkf1ol5z0glfmukvjtvs07zzmd0 [following]
# --2023-06-18 08:10:23--  https://keio.app.box.com/public/static/9lk6sqkf1ol5z0glfmukvjtvs07zzmd0
# Resolving keio.app.box.com (keio.app.box.com)... 74.112.186.144
# Connecting to keio.app.box.com (keio.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!KzuoKrOqB47c9DwjLaA7OKdp8IqXNsakhrz-PcoKSnX6-7o2dmlX6wTonORcEERoL3q8fZjAiPYJZPlsVjS31IJ_qu7I34kR6439I5dr76TuhhlIjHI2hcNhw-PIbeb-z9emAQler6xfR8N1LwliXC38tJLRFKBng4B3x6qVCO4ImaSdCYzqa5NAYSPSJwJOhU45twQ52fDkKVmI9TnssIET8tAE0Pnat4kqyzpoKsUHBjHkfteO2wVnzg57yTllLP8N7G3AAUpEzBKVdgXEcZxvqej28XyF6ICQUEp4wIyhOHSecw4h9sOuGjqUswjlcbzKjqRLc2j3aKhyZLC5eZvJZPT4VqhCixuyX6x6ZUumyh0e989_m1mwnGu92kY3Rpv9u0DyUsBDeUW2ZQNJH-u-peWa1f8HtH0eKxrtcblQWed-NLyYN0FK-m3KX0Krn0ufEmXz2A8N1al--XNRdi5CJnnbfMbqhgBFWqaNzwFhOkD_qajwzLpJKl6MQ-KiNb-vx1-YJICTc4s7EPNLF8rSNPH3tMcWpWpcTCFBvwIOE3KD5-DnxMcWqrzErsoKnfDhs2bXZhumDEiQldJbF0s_kY2cCx57yW9_n-16KARPPxulkAMu317s-PJiMIuc3nduogVWwyZxf4Up1x46dCixPAH0SfTNi6grjNKb5pAFSGYxs02nKxCMrP7_x6DjYQnVrD1EBoV7W1-XY8Vxf5SPGuhxYTWcQjD5diA16rZqWcFYNCTMcFjObyC0LnVb3YI2gRZ9k_g871Nx9ZND_v5ln3YbL5uqROK9rfsMkaK6W4CBd4TAaIGO-6s4cCHXxNig0pVT1Dh6myEzGT2d7WueITtFqkN26hXV5q4Afsod_IZlADyLS2T8Vh4J_qGpQG3PN1GxQc778R_1xSTUXuLP5t5le7BLbhyEOdj_Ug-_2XJbSpHYQreS37BcTqqvBHxWyllr2zWOAJXS7Fe5yzgUxqq4739waG1fcTjcvCEdQkz8p7bqIxdPjJYojE3N3XPXECrZ7aHdN0vd0GL-0sUCk0zwcPFfH3-yTuurPk4sbUORzueekinLWQ7dbB1DLzaB3UXVYuIoy6j5Gl4WQ8SCVXaac3HbIyhmyue108hzdGNWmVu86IvNuZJYvvucuAPvlx-txuNs4Mc-oj9rWw5MgwJV1_rk1KrAh78VtiZPuhcZim7kaoF7phUuZOv_yPzI8GJgv6nNRNCc7UBzuAe7w-zouxFr8FgSJHKdpyiXBrwWjYd9E4Mkb12ithSxkbvpy7LLLiTUrxjfMnpfTfgWNDf7gU4RX9Z8LJTVq1kYrGfttqzh7P63GdlIR0Nx8wyh-v_qXmrpX1Jd8szKVHEvuqP1gAVVuMUuzQa8sy4hzisRhCaoJai5wfLX/download [following]
# --2023-06-18 08:10:24--  https://public.boxcloud.com/d/1/b1!KzuoKrOqB47c9DwjLaA7OKdp8IqXNsakhrz-PcoKSnX6-7o2dmlX6wTonORcEERoL3q8fZjAiPYJZPlsVjS31IJ_qu7I34kR6439I5dr76TuhhlIjHI2hcNhw-PIbeb-z9emAQler6xfR8N1LwliXC38tJLRFKBng4B3x6qVCO4ImaSdCYzqa5NAYSPSJwJOhU45twQ52fDkKVmI9TnssIET8tAE0Pnat4kqyzpoKsUHBjHkfteO2wVnzg57yTllLP8N7G3AAUpEzBKVdgXEcZxvqej28XyF6ICQUEp4wIyhOHSecw4h9sOuGjqUswjlcbzKjqRLc2j3aKhyZLC5eZvJZPT4VqhCixuyX6x6ZUumyh0e989_m1mwnGu92kY3Rpv9u0DyUsBDeUW2ZQNJH-u-peWa1f8HtH0eKxrtcblQWed-NLyYN0FK-m3KX0Krn0ufEmXz2A8N1al--XNRdi5CJnnbfMbqhgBFWqaNzwFhOkD_qajwzLpJKl6MQ-KiNb-vx1-YJICTc4s7EPNLF8rSNPH3tMcWpWpcTCFBvwIOE3KD5-DnxMcWqrzErsoKnfDhs2bXZhumDEiQldJbF0s_kY2cCx57yW9_n-16KARPPxulkAMu317s-PJiMIuc3nduogVWwyZxf4Up1x46dCixPAH0SfTNi6grjNKb5pAFSGYxs02nKxCMrP7_x6DjYQnVrD1EBoV7W1-XY8Vxf5SPGuhxYTWcQjD5diA16rZqWcFYNCTMcFjObyC0LnVb3YI2gRZ9k_g871Nx9ZND_v5ln3YbL5uqROK9rfsMkaK6W4CBd4TAaIGO-6s4cCHXxNig0pVT1Dh6myEzGT2d7WueITtFqkN26hXV5q4Afsod_IZlADyLS2T8Vh4J_qGpQG3PN1GxQc778R_1xSTUXuLP5t5le7BLbhyEOdj_Ug-_2XJbSpHYQreS37BcTqqvBHxWyllr2zWOAJXS7Fe5yzgUxqq4739waG1fcTjcvCEdQkz8p7bqIxdPjJYojE3N3XPXECrZ7aHdN0vd0GL-0sUCk0zwcPFfH3-yTuurPk4sbUORzueekinLWQ7dbB1DLzaB3UXVYuIoy6j5Gl4WQ8SCVXaac3HbIyhmyue108hzdGNWmVu86IvNuZJYvvucuAPvlx-txuNs4Mc-oj9rWw5MgwJV1_rk1KrAh78VtiZPuhcZim7kaoF7phUuZOv_yPzI8GJgv6nNRNCc7UBzuAe7w-zouxFr8FgSJHKdpyiXBrwWjYd9E4Mkb12ithSxkbvpy7LLLiTUrxjfMnpfTfgWNDf7gU4RX9Z8LJTVq1kYrGfttqzh7P63GdlIR0Nx8wyh-v_qXmrpX1Jd8szKVHEvuqP1gAVVuMUuzQa8sy4hzisRhCaoJai5wfLX/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 74.112.186.128
# Connecting to public.boxcloud.com (public.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35193282 (34M) [application/octet-stream]
# Saving to: ‘enwik8.tgz’
#
# enwik8.tgz          100%[===================>]  33.56M  9.54MB/s    in 3.5s
#
# 2023-06-18 08:10:27 (9.54 MB/s) - ‘enwik8.tgz’ saved [35193282/35193282]

# %%
# !pip install ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1

# %%
import json
import random
import time
import math
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.cpp_extension import load
from torch.utils.data import Dataset
import math
import logging
import datetime
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cuda.matmul.allow_tf32 = True

### Step 1: set training data ##########################################################################

datafile = "enwik8"
datafile_encoding = 'utf-8'
# datafile_encoding = 'utf-16le'

### Step 2: set model size #############################################################################

ctx_len = 1024        # ===> increase T_MAX in model.py if your ctx_len > 1024
n_layer = 6
n_embd = 512

# 'RWKV' (better for char-level English) or 'RWKV-ffnPre' (better in some cases)
model_type = 'RWKV'

### Step 3: set batch size #############################################################################

# ===> batch_size must be divisible by B_GROUP_FORWARD and B_GROUP_BACKWARD in model.py
# For example, if your batch_size = 20, you can set B_GROUP_FORWARD = 4, B_GROUP_BACKWARD = 2
# If you see "CUDA out of memory", reduce it. Use GPU-Z to find the highest value for your VRAM.
batch_size = 12

### Step 4: set learning rate, training mini-epochs #######################################################

lr_init = 6e-4
lr_final = 1e-5
# the mini-epoch is very short and of fixed length (ctx_len * epoch_length_fixed tokens)
n_epoch = 500
# 0 = never, 1 = every mini-epoch, 2 = every two mini-epochs, etc.
epoch_save_frequency = 30
epoch_save_path = 'trained-'

epoch_length_fixed = 10000

# %%
########################################################################################################
# CUDA Kernel
########################################################################################################

T_MAX = 1024          # increase this if your ctx_len > 1024
B_GROUP_FORWARD = 4   # set to 8 for best performance
B_GROUP_BACKWARD = 2  # set to 2 for best performance

timex_cuda = load(name="timex", sources=["cuda/timex_op.cpp", "cuda/timex_cuda.cu"],
                  verbose=True, extra_cuda_cflags=['--use_fast_math', '--extra-device-vectorization', f'-DTmax={T_MAX}', f'-DBF={B_GROUP_FORWARD}', f'-DBB={B_GROUP_BACKWARD}'])


class TimeX(torch.autograd.Function):
    @staticmethod
    def forward(ctx, w, k, B, C, T, eps):
        ctx.B = B
        ctx.C = C
        ctx.T = T
        assert ctx.T % 4 == 0 and ctx.T <= T_MAX and ctx.B % B_GROUP_FORWARD == 0 and ctx.B % B_GROUP_BACKWARD == 0
        w = w.contiguous()
        k = k.contiguous()
        ctx.save_for_backward(w, k)
        wk = torch.empty((B, C, T), device='cuda',
                         memory_format=torch.contiguous_format)
        timex_cuda.forward(w, k, wk, eps, B, C, T)
        return wk

    @staticmethod
    def backward(ctx, gwk):
        assert ctx.T % 4 == 0 and ctx.T <= T_MAX and ctx.B % B_GROUP_FORWARD == 0 and ctx.B % B_GROUP_BACKWARD == 0
        w, k = ctx.saved_tensors
        gw = torch.empty((ctx.B, ctx.C, ctx.T), device='cuda',
                         memory_format=torch.contiguous_format)
        gk = torch.empty((ctx.B, ctx.C, ctx.T), device='cuda',
                         memory_format=torch.contiguous_format)
        timex_cuda.backward(w, k, gwk.contiguous(), gw,
                            gk, ctx.B, ctx.C, ctx.T)
        return (gw.sum(dim=0), gk, None, None, None, None)
# Out:
# Using /root/.cache/torch_extensions/py310_cu118 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py310_cu118/timex...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py310_cu118/timex/build.ninja...
# Building extension module timex...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module timex...

# %%
########################################################################################################
# RWKV: RWKV Time-mix + RWKV Channel-mix
########################################################################################################


RWKV_K_CLAMP = 60  # e^60 = 1e26
RWKV_K_EPS = 1e-16
RWKV_HEAD_QK_DIM = 256


def RWKV_Init(module, config):  # fancy initialization of all lin & emb layer in the module
    for m in module.modules():
        if not isinstance(m, (nn.Linear, nn.Embedding)):
            continue
        with torch.no_grad():
            name = '[unknown weight]'
            for name, parameter in module.named_parameters():  # find the name of the weight
                if id(m.weight) == id(parameter):
                    break

            shape = m.weight.data.shape
            gain = 1.0
            scale = 1.0  # extra scale for gain

            if isinstance(m, nn.Embedding):
                gain = math.sqrt(max(shape[0], shape[1]))
                if shape[0] == config.vocab_size and shape[1] == config.n_embd:  # token emb?
                    scale = 1e-4
                else:
                    scale = 0

            if isinstance(m, nn.Linear):
                if m.bias is not None:
                    m.bias.data.zero_()
                if shape[0] > shape[1]:
                    gain = math.sqrt(shape[0] / shape[1])
                if shape[0] == config.vocab_size and shape[1] == config.n_embd:  # final projection?
                    scale = 0.5

            if hasattr(m, 'scale_init'):
                scale = m.scale_init

            # print(str(shape[0]).ljust(5), str(shape[1]).ljust(5), f'{round(scale,2):g}'.ljust(4), name)

            gain *= scale
            if scale == -999:
                nn.init.eye_(m.weight)
            elif gain == 0:
                # zero init is great for some RWKV matrices
                nn.init.zeros_(m.weight)
            elif gain > 0:
                nn.init.orthogonal_(m.weight, gain=gain)
            else:
                nn.init.normal_(m.weight, mean=0.0, std=-scale)

class RWKV_TimeMix(nn.Module):
    def __init__(self, config, layer_id):
        super().__init__()
        self.layer_id = layer_id
        self.ctx_len = config.ctx_len
        self.n_embd = config.n_embd

        attn_sz = config.n_embd

        ############# fancy init of time_w curves ###################################
        f1_begin = 3.0
        f1_end = 1.2
        f2_begin = 0.65
        f2_end = 0.4
        with torch.no_grad():  # initial time_w curves for better convergence
            decay_speed = torch.ones(attn_sz, 1)
            first_sa_layer_id = 1
            for h in range(attn_sz):
                f1 = f1_begin + (layer_id-first_sa_layer_id) / \
                    (config.n_layer-1-first_sa_layer_id) * (f1_end - f1_begin)
                f2 = f2_begin + (layer_id-first_sa_layer_id) / \
                    (config.n_layer-1-first_sa_layer_id) * (f2_end - f2_begin)
                if layer_id == first_sa_layer_id:
                    f1 += 0.5
                if layer_id == config.n_layer-2:
                    f2 = 0.4
                if layer_id == config.n_layer-1:
                    f2 = 0.37
                decay_speed[h][0] = math.pow(f2, h / (attn_sz-1) * 7) * f1
        self.time_decay = nn.Parameter(torch.log(decay_speed)) # will use exp(self.time_decay) to ensure time_decay > 0
        self.time_curve = torch.tensor(
            [-(config.ctx_len - 2 - i) for i in range(config.ctx_len-1)]).unsqueeze(0)
        self.time_curve = self.time_curve.to('cuda')
        self.time_first = nn.Parameter(torch.ones(attn_sz, 1) * math.log(0.3))
        #############################################################################

        self.time_shift = nn.ZeroPad2d((0, 0, 1, -1))
        with torch.no_grad():  # init to "shift half of the channels"
            ww = torch.ones(1, 1, config.n_embd)
            for i in range(config.n_embd // 2):
                ww[0, 0, i] = 0
        self.time_mix = nn.Parameter(ww)

        self.key = nn.Linear(config.n_embd, attn_sz, bias=False)
        self.value = nn.Linear(config.n_embd, attn_sz, bias=False)
        self.receptance = nn.Linear(config.n_embd, attn_sz, bias=False)

        self.output = nn.Linear(attn_sz, config.n_embd, bias=False)

        self.key.scale_init = 0
        self.receptance.scale_init = 0
        self.output.scale_init = 0

    def forward(self, x):
        B, T, C = x.size()

        x = x * self.time_mix + self.time_shift(x) * (1 - self.time_mix)

        k = self.key(x).transpose(-1, -2)
        v = self.value(x).transpose(-1, -2)
        r = self.receptance(x)

        # RWKV_K_CLAMP can be removed if the CUDA kernel substracts the correct k_max for each k (I will do this later)
        k = torch.clamp(k, max=RWKV_K_CLAMP)
        k = torch.exp(k)
        kv = k * v

        self.time_w = torch.cat(
            [torch.exp(self.time_decay) * self.time_curve, self.time_first], dim=-1)
        w = torch.exp(self.time_w)

        wkv = TimeX.apply(w, kv, B, C, T, 0)
        # RWKV_K_EPS can be removed if the CUDA kernel sets 0/0 = 0 (I will do this later)
        wk = TimeX.apply(w, k, B, C, T, RWKV_K_EPS)

        rwkv = torch.sigmoid(r) * (wkv / wk).transpose(-1, -2)
        rwkv = self.output(rwkv)
        return rwkv


class RWKV_ChannelMix(nn.Module):
    def __init__(self, config, layer_id):
        super().__init__()
        self.layer_id = layer_id

        self.time_shift = nn.ZeroPad2d((0, 0, 1, -1))

        with torch.no_grad():  # init to "shift half of the channels"
            x = torch.ones(1, 1, config.n_embd)
            for i in range(config.n_embd // 2):
                x[0, 0, i] = 0
        self.time_mix = nn.Parameter(x)

        hidden_sz = 4 * config.n_embd
        self.key = nn.Linear(config.n_embd, hidden_sz, bias=False)
        self.receptance = nn.Linear(config.n_embd, config.n_embd, bias=False)
        self.value = nn.Linear(hidden_sz, config.n_embd, bias=False)

        self.value.scale_init = 0
        self.receptance.scale_init = 0

    def forward(self, x):
        x = x * self.time_mix + self.time_shift(x) * (1 - self.time_mix)

        k = self.key(x)
        k = torch.square(torch.relu(k))
        kv = self.value(k)

        rkv = torch.sigmoid(self.receptance(x)) * kv
        return rkv

# %%
########################################################################################################
# The GPT Model with our blocks
########################################################################################################

class GPTConfig:
    def __init__(self, vocab_size, ctx_len, **kwargs):
        self.vocab_size = vocab_size
        self.ctx_len = ctx_len
        for k, v in kwargs.items():
            setattr(self, k, v)

class Block(nn.Module):
    def __init__(self, config, layer_id):
        super().__init__()
        self.config = config
        self.layer_id = layer_id

        self.ln1 = nn.LayerNorm(config.n_embd)
        self.ln2 = nn.LayerNorm(config.n_embd)

        if self.layer_id == 0 and self.config.model_type == 'RWKV-ffnPre':
            self.ffnPre = RWKV_ChannelMix(config, layer_id+1000)
        else:
            self.att = RWKV_TimeMix(config, layer_id)

        self.ffn = RWKV_ChannelMix(config, layer_id)

    def forward(self, x):
        x = self.ln1(x)
        if self.layer_id == 0 and self.config.model_type == 'RWKV-ffnPre':
            x = x + self.ffnPre(x)  # better in some cases
        else:
            x = x + self.att(x)
        x = self.ln2(x)
        x = x + self.ffn(x)
        return x

class GPT(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.step = 0
        self.config = config

        self.emb = nn.Embedding(config.vocab_size, config.n_embd)

        self.blocks = nn.Sequential(*[Block(config, i)
                                    for i in range(config.n_layer)])

        self.ln_out = nn.LayerNorm(config.n_embd)
        self.head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

        self.head_q = nn.Linear(config.n_embd, RWKV_HEAD_QK_DIM, bias=False)
        self.head_q.scale_init = 0
        self.head_k = nn.Linear(config.n_embd, RWKV_HEAD_QK_DIM, bias=False)
        self.head_k.scale_init = 0.1
        self.register_buffer("copy_mask", torch.tril(
            torch.ones(config.ctx_len, config.ctx_len)))

        self.ctx_len = config.ctx_len

        RWKV_Init(self, config)

        logger.info("number of parameters: %e", sum(p.numel()
                    for p in self.parameters()))

    def get_ctx_len(self):
        return self.ctx_len

    def _init_weights(self, module):
        if isinstance(module, (nn.Linear)):
            module.weight.data.normal_(mean=0.0, std=0.01)
        if isinstance(module, (nn.Embedding)):
            module.weight.data.normal_(mean=0.0, std=1e-5)
        if isinstance(module, nn.Linear) and module.bias is not None:
            module.bias.data.zero_()

    def configure_optimizers(self, train_config):
        # separate out all parameters to those that will and won't experience regularizing weight decay
        decay = set()
        no_decay = set()

        for mn, m in self.named_modules():  # here we disable weight_decay
            for pn, p in m.named_parameters():
                fpn = '%s.%s' % (mn, pn) if mn else pn  # full param name
                no_decay.add(fpn)

        param_dict = {pn: p for pn, p in self.named_parameters()}
        inter_params = decay & no_decay
        union_params = decay | no_decay
        assert len(
            inter_params) == 0, "parameters %s made it into both decay/no_decay sets!" % (str(inter_params), )
        assert len(param_dict.keys() - union_params) == 0, "parameters %s were not separated into either decay/no_decay set!" \
            % (str(param_dict.keys() - union_params), )

        optim_groups = [
            {"params": [param_dict[pn]
                        for pn in sorted(list(no_decay))], "weight_decay": 0.0},
        ]

        optimizer = torch.optim.Adam(
            optim_groups, lr=train_config.learning_rate, betas=train_config.betas, eps=train_config.eps)

        return optimizer

    def forward(self, idx, targets=None):
        self.step += 1
        B, T = idx.size()
        assert T <= self.ctx_len, "Cannot forward, because len(input) > model ctx_len."
        x = self.emb(idx)

        x = self.blocks(x)

        x = self.ln_out(x)

        q = self.head_q(x)[:, :T, :]
        k = self.head_k(x)[:, :T, :]
        c = (q @ k.transpose(-2, -1)) * (1.0 / RWKV_HEAD_QK_DIM)
        c = c.masked_fill(self.copy_mask[:T, :T] == 0, 0)

        c = c @ F.one_hot(idx, num_classes=self.config.vocab_size).float()
        x = self.head(x) + c

        loss = None
        if targets is not None:
            loss = F.cross_entropy(x.view(-1, x.size(-1)), targets.view(-1))

        return x, loss

# %%
########################################################################################################
# The RWKV v2-RNN Language Model - https://github.com/BlinkDL/RWKV-LM
########################################################################################################

class Dataset(Dataset):
    def __init__(self, data, ctx_len, epoch_length_fixed):
        print('building token list...', end=' ')
        unique = sorted(list(set(data)))
        # print()
        # for u in unique:
        #     print(u, end=' ')
        # print('\n\n')

        xx = 0
        xxObj = {}
        for u in unique:
            xxObj[xx] = u
            xx += 1
        with open('vocab.json', "w", encoding="utf-16") as vocab_file:
            vocab_file.write(json.dumps(xxObj, ensure_ascii=False))

        data_size, vocab_size = len(data), len(unique)
        print('data has %d tokens, %d unique.' % (data_size, vocab_size))
        self.stoi = {ch: i for i, ch in enumerate(unique)}
        self.itos = {i: ch for i, ch in enumerate(unique)}
        self.ctx_len = ctx_len
        self.epoch_length_fixed = epoch_length_fixed
        self.vocab_size = vocab_size
        self.data = data

    def __len__(self):
        return self.epoch_length_fixed

    def __getitem__(self, idx):
        # cheat: pick a random spot in dataset
        i = np.random.randint(0, len(self.data) - (self.ctx_len + 1))
        chunk = self.data[i:i+self.ctx_len+1]
        dix = [self.stoi[s] for s in chunk]
        x = torch.tensor(dix[:-1], dtype=torch.long,
                         device=torch.device('cuda'))
        y = torch.tensor(dix[1:], dtype=torch.long,
                         device=torch.device('cuda'))
        return x, y


class TOKENIZER():
    def __init__(self, WORD_NAME, UNKNOWN_CHAR='\ue083'):
        with open(WORD_NAME + '.json', "r", encoding="utf-16") as result_file:
            self.word_table = json.load(result_file)

        self.vocab_size = len(self.word_table)

        self.stoi = {v: int(k) for k, v in self.word_table.items()}
        self.itos = {int(k): v for k, v in self.word_table.items()}

        self.UNKNOWN_CHAR = self.stoi[UNKNOWN_CHAR]

    def refine_context(self, context):
        context = context.strip().split('\n')
        for c in range(len(context)):
            context[c] = context[c].strip().strip('\u3000').strip('\r')
        context = list(filter(lambda c: c != '', context))
        context = '\n' + ('\n'.join(context)).strip()
        if context == '':
            context = '\n'

        return context

    def sample_logits(self, out, x, ctx_len, temperature=1.0, top_p_usual=None, top_p_newline=None):
        # out[self.UNKNOWN_CHAR] = -float('Inf')

        lastChar = int(x[-1])

        probs = F.softmax(torch.tensor(out), dim=-1)

        if self.itos[lastChar] == '\n':
            top_p = top_p_newline
        else:
            top_p = top_p_usual

        sorted_probs, s_index = torch.sort(probs, descending=True)

        # for j in range(30):
        #     pp = sorted_probs[j].item()
        #     if pp < 0.005:
        #         break
        #     ss = self.itos[int(s_index[j])].replace('\n','_')
        #     print(f'{math.floor(pp*100):>3.0f}{ss}', end='')
        # print('')

        cumulative_probs = torch.cumsum(sorted_probs, dim=-1).numpy()
        cutoff = float(sorted_probs[np.argmax(cumulative_probs > top_p)])

        probs[probs < cutoff] = 0
        # print("[" + str(round(cutoff,4)) + ' ' + str(round(to_float(sum(probs)),3)) + "]", end = "")

        if temperature != 1.0:
            probs = probs.pow(1.0 / temperature)

        return torch.multinomial(probs, num_samples=1)[0]


def to_float(x):
    return x.cpu().detach().numpy().flatten()[0].astype(float)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
########################################################################################################
# The RWKV v2-RNN Language Model - https://github.com/BlinkDL/RWKV-LM
########################################################################################################

from torch.utils.data.dataloader import DataLoader
from torch.optim.lr_scheduler import LambdaLR
from torch.nn import functional as F
import torch.nn as nn
import torch.optim as optim
import torch
from tqdm.auto import tqdm
import numpy as np
import logging
import os
import datetime
import sys
import math

# import wandb  # comment this if you don't have wandb
# print('logging to wandb... (comment it if you don\'t have wandb)')

logger = logging.getLogger(__name__)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cuda.matmul.allow_tf32 = True

log_file = open("mylog.txt", "a")


class TrainerConfig:
    max_epochs = 10
    batch_size = 64
    learning_rate = 4e-4
    betas = (0.9, 0.99)
    eps = 1e-8
    grad_norm_clip = 1.0
    lr_decay = True  # linear warmup followed by cosine decay
    warmup_tokens = 0
    final_tokens = 0
    epoch_save_frequency = 0
    epoch_save_path = 'trained-'
    num_workers = 0  # for DataLoader

    def __init__(self, **kwargs):
        for k, v in kwargs.items():
            setattr(self, k, v)


class Trainer:

    def __init__(self, model, train_dataset, test_dataset, config):
        self.model = model
        self.train_dataset = train_dataset
        self.test_dataset = test_dataset
        self.config = config
        self.avg_loss = -1
        self.steps = 0

        if 'wandb' in sys.modules:
            cfg = model.config
            for k in config.__dict__:
                setattr(cfg, k, config.__dict__[k])  # combine cfg
            wandb.init(project="RWKV-LM", name=self.get_run_name() + '-' +
                       datetime.datetime.today().strftime('%Y-%m-%d-%H-%M-%S'), config=cfg, save_code=False)

        self.device = 'cpu'
        if torch.cuda.is_available():  # take over whatever gpus are on the system
            self.device = torch.cuda.current_device()

    def get_run_name(self):
        raw_model = self.model.module if hasattr(
            self.model, "module") else self.model
        cfg = raw_model.config
        run_name = str(cfg.vocab_size) + '-' + str(cfg.ctx_len) + '-' + \
            cfg.model_type + '-' + str(cfg.n_layer) + '-' + str(cfg.n_embd)
        return run_name

    def train(self):
        model, config = self.model, self.config
        raw_model = model.module if hasattr(self.model, "module") else model
        optimizer = raw_model.configure_optimizers(config)

        def run_epoch(split):
            is_train = split == 'train'
            model.train(is_train)
            data = self.train_dataset if is_train else self.test_dataset

            if config.num_workers > 0:
                loader = DataLoader(data, shuffle=False, pin_memory=True,
                                    batch_size=config.batch_size,
                                    num_workers=config.num_workers)
            else:
                loader = DataLoader(data, shuffle=False,
                                    batch_size=config.batch_size,
                                    num_workers=config.num_workers)

            pbar = tqdm(enumerate(loader), total=len(
                loader), bar_format='{l_bar}{bar:10}{r_bar}{bar:-10b}') if is_train else enumerate(loader)

            for it, (x, y) in pbar:
                x = x.to(self.device)  # place data on the correct device
                y = y.to(self.device)

                with torch.set_grad_enabled(is_train):
                    _, loss = model(x, y)  # forward the model

                if is_train:  # backprop and update the parameters
                    model.zero_grad()
                    loss.backward()

                    if config.grad_norm_clip > 0:
                        torch.nn.utils.clip_grad_norm_(
                            model.parameters(), config.grad_norm_clip)

                    optimizer.step()

                    if config.lr_decay:  # decay the learning rate based on our progress
                        # number of tokens processed this step (i.e. label is not -100)
                        self.tokens += (y >= 0).sum()
                        lr_final_factor = config.lr_final / config.learning_rate
                        if self.tokens < config.warmup_tokens:
                            # linear warmup
                            lr_mult = lr_final_factor + \
                                (1 - lr_final_factor) * float(self.tokens) / \
                                float(config.warmup_tokens)
                            progress = 0
                        else:
                            # cosine learning rate decay
                            progress = float(self.tokens - config.warmup_tokens) / float(
                                max(1, config.final_tokens - config.warmup_tokens))
                            lr_mult = (0.5 + lr_final_factor / 2) + (0.5 - lr_final_factor /
                                                                     2) * math.cos(math.pi * progress)  # better 1.0 ~ 0.1
                        lr = config.learning_rate * lr_mult
                        for param_group in optimizer.param_groups:
                            param_group['lr'] = lr
                    else:
                        lr = config.learning_rate

                    now_loss = loss.item()  # report progress
                    self.lr = lr

                    if 'wandb' in sys.modules:
                        wandb.log({"loss": now_loss},
                                  step=self.steps * self.config.batch_size)
                    self.steps += 1

                    if self.avg_loss < 0:
                        self.avg_loss = now_loss
                    else:
                        factor = 1 / (it + 1)
                        self.avg_loss = self.avg_loss * \
                            (1.0 - factor) + now_loss * factor
                    pbar.set_description(
                        f"mini-epoch {epoch+1} prog {progress*100.0:.2f}% iter {it}: ppl {math.exp(self.avg_loss):.2f} loss {self.avg_loss:.4f} lr {lr:e}")

        self.tokens = 0  # counter used for learning rate decay
        for epoch in range(config.max_epochs):

            run_epoch('train')

            log_file.write(
                f'{epoch+1} {self.avg_loss:.6f} {math.exp(self.avg_loss):.4f} {self.lr:.8f} {datetime.datetime.now()} \n')
            log_file.flush()

            if (self.config.epoch_save_frequency > 0 and epoch % self.config.epoch_save_frequency == 0) or (epoch == config.max_epochs - 1):
                # DataParallel wrappers keep raw model object in .module
                raw_model = self.model.module if hasattr(
                    self.model, "module") else self.model
                torch.save(raw_model.state_dict(),
                           self.config.epoch_save_path + str(epoch+1) + '.pth')

# %%
########################################################################################################

# import src.utils
# src.utils.set_seed(42) # remember to change seed if you load a model

np.set_printoptions(precision=4, suppress=True, linewidth=200)
logging.basicConfig(format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
                    datefmt="%Y-%m-%d %H:%M:%S", level=logging.INFO,)

grad_norm_clip = 1.0
warmup_tokens = 0

betas = (0.9, 0.99)
eps = 4e-9

num_workers = 0

########################################################################################################
# Load data
########################################################################################################

print('loading data... ' + datafile)
train_dataset = Dataset(open(
    datafile, "r", encoding=datafile_encoding).read(), ctx_len, epoch_length_fixed)

########################################################################################################
# Train model
########################################################################################################
model = GPT(GPTConfig(train_dataset.vocab_size, train_dataset.ctx_len, model_type=model_type,
                      n_layer=n_layer, n_embd=n_embd)).cuda()

# # # load a trained model. remember to change random seed
# m2 = torch.load('trained-61.pth')
# model.load_state_dict(m2)

print('model', model_type, 'epoch', n_epoch, 'batchsz', batch_size, 'betas',
      betas, 'eps', eps, 'ctx', ctx_len, 'layer', n_layer, 'embd', n_embd, )
tconf = TrainerConfig(model_type=model_type, max_epochs=n_epoch, batch_size=batch_size,
                      learning_rate=lr_init, lr_decay=True, lr_final=lr_final, betas=betas, eps=eps, grad_norm_clip=grad_norm_clip,
                      warmup_tokens=warmup_tokens, final_tokens=n_epoch*len(train_dataset)*ctx_len, num_workers=num_workers, epoch_save_frequency=epoch_save_frequency, epoch_save_path=epoch_save_path)
trainer = Trainer(model, train_dataset, None, tconf)

trainer.train()

savepthname = 'trained-' + str(n_epoch) + '-' + trainer.get_run_name() + \
            '-' + datetime.datetime.today().strftime('%Y-%m-%d-%H-%M-%S') + '.pth'

torch.save(model.state_dict(), savepthname)
# Out:
# loading data... enwik8
# building token list... data has 99621832 tokens, 6064 unique.
# model RWKV epoch 500 batchsz 12 betas (0.9, 0.99) eps 4e-09 ctx 1024 layer 6 embd 512
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
#   0%|          | 0/834 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-553162573ff3> in <cell line: 49>()
#      47
#      48 torch.save(model.state_dict(), savepthname)
# ---> 49 torch.save(model.state_dict(), 'drive/' + savepthname)
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     438
#     439     if _use_new_zipfile_serialization:
# --> 440         with _open_zipfile_writer(f) as opened_zipfile:
#     441             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442             return
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_zipfile_writer(name_or_buffer)
#     313     else:
#     314         container = _open_zipfile_writer_buffer
# --> 315     return container(name_or_buffer)
#     316
#     317
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name)
#     286 class _open_zipfile_writer_file(_opener):
#     287     def __init__(self, name) -> None:
# --> 288         super().__init__(torch._C.PyTorchFileWriter(str(name)))
#     289
#     290     def __exit__(self, *args) -> None:
#
# RuntimeError: File drive/trained-500-6064-1024-RWKV-6-512-2023-06-18-18-50-54.pth cannot be opened.

# %%
torch.save(model.state_dict(), 'drive/MyDrive/' + savepthname)

# %% [markdown]
# ここまでが上手くいけば、問題なく動作するはずである
#
# 計算コストが大きく学習できなかった場合は、あらかじめ準備した学習結果をロードして続きを実行すること

# %%
RWKV_K_CLAMP = 60
RWKV_K_EPS = 1e-16
RWKV_HEAD_QK_DIM = 256

DEBUG_TIME = False   # True False - show trained time-coeffs


class RWKV_RNN():
    def __init__(self, MODEL_NAME, RUN_DEVICE, model_type, n_layer, n_embd, ctx_len):
        self.RUN_DEVICE = RUN_DEVICE
        self.model_type = model_type
        self.n_layer = n_layer
        self.n_embd = n_embd
        self.ctx_len = ctx_len

        self.w = types.SimpleNamespace()

        w = torch.load(MODEL_NAME + '.pth',
                       map_location=torch.device(RUN_DEVICE))
        for x in w.keys():
            if '.time_' in x:
                w[x] = w[x].squeeze()
            if '.time_decay' in x:
                w[x] = torch.exp(-torch.exp(w[x]))
            if '.time_first' in x:
                w[x] = torch.exp(w[x])
            if DEBUG_TIME and '.time_' in x:
                print(x, w[x].squeeze().cpu().numpy())

            xx = x.split('.')
            here = self.w
            for i in range(len(xx)):
                if xx[i].isdigit():
                    ii = int(xx[i])
                    if ii not in here:
                        here[ii] = types.SimpleNamespace()
                    here = here[ii]
                else:
                    if i == len(xx) - 1:
                        setattr(here, xx[i], w[x])
                    elif not hasattr(here, xx[i]):
                        if xx[i+1].isdigit():
                            setattr(here, xx[i], {})
                        else:
                            setattr(here, xx[i], types.SimpleNamespace())
                    here = getattr(here, xx[i])

        self.clear()

    def clear(self):
        self.xx = {}
        self.aa = {}
        self.bb = {}
        self.hk = None

    def save(self, target):
        target.xx = copy.deepcopy(self.xx)
        target.aa = copy.deepcopy(self.aa)
        target.bb = copy.deepcopy(self.bb)
        target.hk = copy.deepcopy(self.hk)

    def load(self, target):
        self.xx = copy.deepcopy(target.xx)
        self.aa = copy.deepcopy(target.aa)
        self.bb = copy.deepcopy(target.bb)
        self.hk = copy.deepcopy(target.hk)

    def LN(self, xx, w):
        return F.layer_norm(xx, (self.n_embd,), weight=w.weight, bias=w.bias)

    def FF(self, xx, w, name):
        if name not in self.xx:
            self.xx[name] = torch.zeros(self.n_embd, device=self.RUN_DEVICE)
        x = xx * w.time_mix + self.xx[name] * (1 - w.time_mix)
        self.xx[name] = xx

        r = torch.sigmoid(w.receptance.weight @ x)
        k = torch.square(torch.relu(w.key.weight @ x))
        kv = w.value.weight @ k

        return r * kv

    def SA(self, xx, w, name):
        if name not in self.xx:
            self.xx[name] = torch.zeros(self.n_embd, device=self.RUN_DEVICE)
            self.aa[name] = torch.zeros(self.n_embd, device=self.RUN_DEVICE)
            self.bb[name] = torch.zeros(self.n_embd, device=self.RUN_DEVICE)
        x = xx * w.time_mix + self.xx[name] * (1 - w.time_mix)
        self.xx[name] = xx

        r = torch.sigmoid(w.receptance.weight @ x)

        k = torch.exp(torch.clamp(w.key.weight @ x, max=RWKV_K_CLAMP))
        v = w.value.weight @ x
        kv = k * v

        a = self.aa[name] + w.time_first * kv
        b = self.bb[name] + w.time_first * k
        self.aa[name] = w.time_decay * self.aa[name] + kv
        self.bb[name] = w.time_decay * self.bb[name] + k

        rwkv = r * a / (b + RWKV_K_EPS)

        return w.output.weight @ rwkv

    def run(self, ctx):
        w = self.w
        x = w.emb.weight[ctx[-1]]

        for i in range(self.n_layer):
            x = self.LN(x, w.blocks[i].ln1)
            if i == 0 and self.model_type == 'RWKV-ffnPre':
                x = x + self.FF(x, w.blocks[i].ffnPre, f'ffnPre.{i}')
            else:
                x = x + self.SA(x, w.blocks[i].att, f'att.{i}')
            x = self.LN(x, w.blocks[i].ln2)
            x = x + self.FF(x, w.blocks[i].ffn, f'ffn.{i}')

        x = self.LN(x, w.ln_out)

        if self.hk == None:
            self.hk = (w.head_k.weight @ x).unsqueeze(0)
        else:
            self.hk = torch.cat(
                [self.hk, (w.head_k.weight @ x).unsqueeze(0)], dim=0)
        if self.hk.shape[0] > self.ctx_len:
            self.hk = self.hk[-self.ctx_len:, :]

        q = w.head_q.weight @ x

        x = w.head.weight @ x
        x = x.cpu().numpy().tolist()

        c = (self.hk @ q) / RWKV_HEAD_QK_DIM
        for i in range(len(c)):
            x[ctx[i]] += c[i]

        return x

# %% [markdown]
# GPT-3などに比較すれば、これでもかなり学習時間や計算コストが小さいが、次のように、文章生成を行うことができる点に注目されたい

# %%
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cuda.matmul.allow_tf32 = True
np.set_printoptions(precision=4, suppress=True, linewidth=200)

### Step 1: set model ##################################################################################

ctx_len = 1024
n_layer = 6
n_embd = 512
model_type = 'RWKV'           # 'RWKV' or 'RWKV-ffnPre'

# your trained model
MODEL_NAME = 'trained-v1'
WORD_NAME = 'vocab'           # the .json vocab (generated by train.py

# ########## Uncomment these to test my 27M params enwik8 model ##########
# MODEL_NAME = 'enwik8-ppl1.65-6064-1024-RWKV-6-512-2022-03-25-21-05-13'
# WORD_NAME = 'enwik8-vocab'
# EVAL_DATA = 'enwik8'  # uncomment this for EVAL MODE (no text generation)
# ########################################################################

# --> set UNKNOWN_CHAR to the rarest token in your vocab.json <--
# --> all unknown tokens in your context will be denoted by it <--
UNKNOWN_CHAR = ' '   # here we just set it to [space] for simplicity

RUN_DEVICE = 'cpu'   # 'cpu' (already very fast) or 'cuda'
DEBUG_DEBUG = False  # True False - show softmax output

### Step 2: set context ################################################################################

context = "\nIn the"       # ==> this is your prompt

NUM_TRIALS = 10
LENGTH_PER_TRIAL = 500

TEMPERATURE = 1.0
top_p = 0.7
top_p_newline = 0.9

########################################################################################################

print(f'Loading {MODEL_NAME}...')
model = RWKV_RNN(MODEL_NAME, RUN_DEVICE, model_type, n_layer, n_embd, ctx_len)
tokenizer = TOKENIZER(WORD_NAME, UNKNOWN_CHAR=UNKNOWN_CHAR)

########################################################################################################

if 'EVAL_DATA' in vars() or 'EVAL_DATA' in globals():
    print('Evaluating on ' + EVAL_DATA + ' ...')

    data = open(EVAL_DATA, "r", encoding='utf-8').read()

    loss_table = np.zeros(ctx_len)

    N_SAMPLE = 1000

    for iii in range(N_SAMPLE):
        pos = np.random.randint(0, len(data) - ctx_len-1)
        context = data[pos:pos+ctx_len+1]
        ctx = [tokenizer.stoi.get(s, tokenizer.UNKNOWN_CHAR) for s in context]

        model.clear()
        for i in range(1, ctx_len+1):
            x = ctx[:i]
            out = model.run(x)
            prob = F.softmax(torch.tensor(out), dim=-1)
            loss_table[i-1] += -math.log(prob[ctx[i]])

        print(f'Tested {iii+1} samples: avg_loss over ctx_len =',
              np.mean(loss_table) / (iii+1))

    exit(0)

########################################################################################################

context = tokenizer.refine_context(context)
print('\nYour prompt has ' + str(len(context)) + ' tokens.')
print('\n--> Currently the first run takes a while if your prompt is long, as we are using RNN to process the prompt. This will be much faster in future versions. <--\n')

for TRIAL in range(1 if DEBUG_DEBUG else NUM_TRIALS):
    t_begin = time.time_ns()

    src_len = len(context)
    ctx = [tokenizer.stoi.get(s, tokenizer.UNKNOWN_CHAR) for s in context]
    print(('-' * 30) + context, end='')

    model.clear()
    if TRIAL == 0:
        init_state = types.SimpleNamespace()
        for i in range(src_len):
            x = ctx[:i+1]
            if i == src_len - 1:
                init_state.out = model.run(x)
            else:
                model.run(x)
        model.save(init_state)
    else:
        model.load(init_state)

    for i in range(src_len, src_len + (1 if DEBUG_DEBUG else LENGTH_PER_TRIAL)):
        x = ctx[:i+1]
        x = x[-ctx_len:]

        if i == src_len:
            out = copy.deepcopy(init_state.out)
        else:
            out = model.run(x)
        if DEBUG_DEBUG:
            print('model', np.array(x), '==>', np.array(
                out), np.max(out), np.min(out))

        char = tokenizer.sample_logits(out, x, ctx_len, temperature=TEMPERATURE,
                                       top_p_usual=top_p, top_p_newline=top_p_newline)
        char = char.item()
        print(tokenizer.itos[int(char)], end='', flush=True)
        ctx += [char]
    t_end = time.time_ns()
    print("\n----------", round((t_end - t_begin) / (10 ** 9), 2), end='s ')
# Out:
# Loading trained-v1...
#
# Your prompt has 7 tokens.
#
# --> Currently the first run takes a while if your prompt is long, as we are using RNN to process the prompt. This will be much faster in future versions. <--
#
# ------------------------------
# In the second part of the term &quot;bare pales.&quot; The term &quot;bare pales.&quot; The term in function is most often used to describe a [[recipe]] from [[constant proture]] in which [[bare paint]] is simply the origin. The term '''bare particular''' is also sometimes used to mean barest, but the neutral version of the term is '''[[Subtropos And Protein]]'''.
#
# Some proteins contain [[tetrapod]]s ([[DNA reptile]]s) or simply [[DNA repair]] proteins ([[ANTICHER|Adenine DNA transport proteins]]).
#
# ---------- 4.94s ------------------------------
# In the case of the [[1860]]s, the first recorded empire of [[Mont Blanc]] and [[England]] was carried into the [[Caribbean]], the smaller white [[monarchy|kingdom]] of [[New Spain]], and a major power in [[North America]]. In the [[Americas]], [[Central America]] and the [[Oceania|South American States of Mibral Island]] were formed, the [[United States]] had to send an additional resting pt to the surrounding territory. The rest of the area is also known as the '''[[Indigenous peoples of the Americas
# ---------- 5.24s ------------------------------
# In the [[1980s]] ([[Australian car horse diesel accurate|AH]] or [[Rush method | Raskin]]), the [[Rush method]] and [[Leap year rule|Leap year]] were adopted in the U.S. At the time, an accurate formula by [[Rush Medical]] was reported to have placed the Rush on the beginning of the Rush on [[August 22]], [[1985]].  The [[Roaring Rush]] was run while [[Andrew Johnson]] stepped into a direction until [[1989]].  It was also the first day of Rush to be a Rush Media Player in [[American Samoa]].  The spee
# ---------- 4.84s ------------------------------
# In the late 1980s the British development of the [[British Forces Regiment (Afghanistan)|british Forces Act]] reduced the defeat of the Forces and allowed the Forces to exercise power in the United Kingdom.  The Forces Act of 1994 adopted a new [[Conscription in the Forces]], which was signed in 2000 by the United States Department of the Intelligence Service (FISS) in the [[United States Army]].
#
# == Protection and external links ==
# * [http://www.ericdigests.org/2003-3/quality.htm On the estimated den
# ---------- 5.09s ------------------------------
# In the 1970s, the early stages of the era were set in [[black-and-white]] complexes, and the majority of them are related to and many products that are now extinct.  The early erupt groups belonging to the eruption of [[Lake Erie]] and the [[Black Sands newspapers|eruption canons]] in the era of settlements in [[New York City]] were once colloquial to some of the newer eras.  The eruption of the lake to [[Chicago, Illinois|Chicago]] saw a significant degree of completion during the 1960s and 1970s.  T
# ---------- 5.01s ------------------------------
# In the [[1960s]] and [[1970s]], it was the standard practice of the survivors of early successful enterprises and was an advanced prophetic statement in the 1970s. In the 1970s the [[Islamist]] movement seized control of [[Morocco]] and [[Arab]] countries and the wealthy community in the region of [[Fez, France]]. The [[Arab League]] has also struggled to create a new cultural and political system for the Islamic world. The concept of &quot;Islamic atomicny&quot; and also of the Islamic forces have se
# ---------- 5.0s ------------------------------
# In the 1970s and 1980s many of the more professionally managed [[first-person shooter]]s in Internet and many were being replaced by a larger number of [[platform game]]s. The first [[Atari 7800]] computer game in the [[United States]] had a large and graphО [[video]] release in [[1973]] for a full six second-lap of [[Microsoft Windows|Windows]].  The game was designed by [[Jack Benz]] and [[Jerry Robinson]] in [[1976]]. It was also the first modern model of a [[graphical user interface]] for all [[mo
# ---------- 5.24s ------------------------------
# In the first decade of the [[19th century]], and the second only to the [[United States]], it was increasingly used by people who came from an unstable farm.  As the cause of the wind was more pronounced and denigrated and a big way for a single capitalist country to remain in the developed world, it is the only such economy to die.  The [[Indian Plan|furnishing]] coup  in [[1948]] was the first country to receive a major transition between the poorer states.  In 1948 [[Washington, D.C.]] ([[Congress
# ---------- 4.93s ------------------------------
# In the last five years after the end of [[World War I]], the death of his parents and his wife Joseph de Huxham's, a secret transfer from [[Arthur Schopenhauer]], the father of [[Joséphine de Beauharnais]].
#
# In [[1918]] he received a [[Psychiatry|psychiatric]] persona and was appointed as the candidate for the [[United Nations]] in the US [[Federal government of the United States]].  In [[1928]] he received the [[1933]] [[Nobel Peace Prize]], and was named the first [[President of the United States]
# ---------- 5.03s ------------------------------
# In the same way, contemporary critics and critics were concerned that the state acted in a manner almost independent of the contentious circumstances that such content was in fact the case for the contrar卌de. The party strengthened the anti-conservative argument by writing to a party as a consequence of the issue. The conservative [[Catholic]] stance theory against the controversial religion saw a consensus as to whether controversy or conservatism is consistent with Catholicism.
#
# Although the separat
# ---------- 4.9s ------------------------------
# In the [[Metal Instrument|Intelligence Opera]] of [[Paul McCartney]], the pseudo space is called [[interactive dialogy]], which utilizes [[data structure]]s. It is a means for a [[telephone]] or [[digital telephone-transmission]] system to be used for communication in a [[printed circuit board]].
#
# ==History==
# [[Image:Edward Elwes 01 solid-solar pair.jpg|thumb|300px|[[Edward Elwes Pailler|Edward Parliament]] campaign for 11 structured and 30 circular [[Palladium]] spiral]]
# The first pairs of circular p
# ---------- 4.87s ------------------------------
# In the mid-1990s, a revival of the Internet had become the mainstay of the Internet and a number of other development attitudes and internal processes.  The Internet also contained [[business continuity]] such as interactive web sites and [[monopoly]] requirements.
#
# By 1995, it was selling products to finance [[subscriber configurationing|SCS]] and [[computer printer|printers]] to provide such a power for Intel and other computers. Intelligent documents are available to store its [[proprietary]] [[sof
# ---------- 5.31s ------------------------------
# In the [[United Kingdom]], '''[[animal rights]]''' are seen as the product of such property because they spend the majority of the film only in the sense that they have a strong and diverse concept. They are capable of consenting and there must be some consequences of commanding and the production in question or the struggle for interference or dissolution.
#
# '''[[Camera]]''' is an international animation program and is a self-supporting animation format with many stories about the evolution of modern
# ---------- 4.9s ------------------------------
# In the [[1970s]], [[World War II]] ended with the [[Arab Tribes | tribal Egypt]] and the [[Bahmani Equator]]. As the [[United States]] experienced a profound crisis of fierce rivalry, ensuring a long distance between the two countries.  [[Mohammad Reza Pahlavi|Mohammad Reza Shah Pahlavi's]] father [[Abdul Rahman Hussayen]], a few months after his death, were to provide a powerful and sustainable alternative. However, the move also continued following the [[Iranian Revolution]] in [[South East Asia]],
# ---------- 4.95s ------------------------------
# In the [[1990s]], Afghanistan was divided into two parts: the various divisions between the army and the former Soviet Union. The last entry of the Soviet Union in 1991 took place in Soviet territory to the east and west coasts of the Balkans. In 1995, a six-year entered political and envoy who launched a mass exodus of around 100,000 people into the islands and resided on the island. Also in 1995, a record 18 years ago was in spite of Afghanistan's remaining provinces. The territory of the North Kore
# ---------- 5.15s ------------------------------
# In the early 1980s, Australian light fish were introduced into Australia, which contained a small family all-weather target. The Australian electricity transfer helicopter was introduced to Europe in 1984 and the [[United States|U.S.]] base in 1996. In 1998, Australia became the first subsidiary of Australia to receive the [[Prime Minister's Approved Commission]] (PCA). In 1998, the Australian government announced its cometary questionnaire ''&quot;I have a space on a well meeted tree in [[Mexico]] an
# ---------- 4.98s ------------------------------
# In the 1960s, a major distinction between the elements of the artistic and critical and practical artistic phenomena in the 1960s. For example, some of the artists of the 1960s and 1970s have a single artistic artistic and popular artistic achievement. The standard artistic and environmental area of artistic politics was the [[Autopassing_Consent_Number|National Autonomous Consent]].
#
# The popularity of artistic artistic artistic techniques is mostly disputed by critics who point out that while the ar
# ---------- 5.13s ------------------------------
# In the United States, the name ''Indiana'' is the [[pronun起roved|province]] of [[Indiana]], and the surrounding northwest from the [[Pacific Northwest]]. The province of the [[Indiana of Colorado]] is the largest city in the [[United States]], and is sometimes referred to as the &quot;Indiana of the Indians&quot; (see [[Indiana of the Indian army]]).
#
# ==Geography==
# [[Image:Atlanta1910.jpg|thumb|right|200px|Physical and musical features of the Indiana area]]
# {{main|Geography of Indiana}}
# Indiana is loc
# ---------- 4.89s ------------------------------
# In the context of conservative media protests, the first serious new work was created for the conservative government of [[John Major]], a member of the [[British Academy of Fine Arts]].  In the same year (1965) it became a case in which [[Walter Brennan]] became a professional scholar at the [[University of Cambridge]]. In 1968 he published a number of works on the work of [[Alfred Russel Wallace]], and the subsequent articles from his summarized songs &quot;[[Martin Ryle]],&quot; &quot;[[Martyrdom]]
# ---------- 5.1s ------------------------------
# In the [[United States]], a few subtle [[counterculture|countercultural]] theories have come to later benefit in the process of being culturally respected and difficult to identify. This is a key issue for some of the development of [[ethnocentric]] theories.
#
# For example, the work of [[Allen Lanier]] ([[1966]]), whose ''New Encyclopedia of Clinical and Experimental Development'' ([[1967]]) was in a series of examples that examine the processes of clinical trials with [[psychology|psychological]] expe
# ---------- 5.09s ------------------------------
# In the 1989 story &quot;Lightning Things&quot;, [[James Collip]] claims that the color in a flame on the street is a thought that the story is mentioned in the [[Colorado Front Dispute]] book ''[[The Evolution of Art]]''.
#
# The term &quot;flame war&quot; is now used in the [[Western world]], the study of the modern forms of [[history]] of the [[Science Fiction Magazine]] and the [[American Psychological Association]]. In the 1960s, the term ''flamenco flamenco space'' applied to the term &quot;flamenco
# ---------- 4.99s ------------------------------
# In the [[1970s]] a growing move from the commercial sector of Boston's econdary airlines to the region wearing simultaneously to Boston all the way to [[United States|U.S.]] and [[Canada]].  The entire two albums 萨 made an appearance at the 1972 Freehands events, the then 1973 single &quot;I Love the Night.&quot;  Also in 1973, the 1973 third album, ''[[Starside]]'', was released as a single dubbed the &quot;New York Times&quot;.  The album was recorded in 2004 for $25 million.  The album was finally
# ---------- 5.25s ------------------------------
# In the semantic field of [[science fiction]], [[dystopia]]ns and [[literary criticism|literary critics]] at [[multiple colleges]] have emerged as colleges and universities in a wide variety of subjects. In the [[1970s]] the [[International Organization for Standardization]] (ISO) was established in [[1975]].
#
# ==History==
#
# The ISO standard is a leading [[standardized text]] and used by some to be a standard textbook.  In the [[1980s]], [[Mass media]] began to be read by a single commentator on [[Assass
# ---------- 4.91s ------------------------------
# In the mid-[[1980s]], the [[John Lennon]]-based American [[pseudonym]] (&quot;[[Bliss (singer)|Bliss]]&quot;) came to denunciation American science fiction [[alternate use | alternatively]] as an alternative to &quot;[[subject (philosophy)|subject]]&quot; for the album ''[[The Black Adder]]''.
#
# In [[1985]], a political [[stereotype]] identified America as a [[populist]] [[sensation studio]], the ''[[America (album)|America]]'' started a [[satire|satirical]] programme on the streets of [[Los Angeles, C
# ---------- 5.1s ------------------------------
# In the [[1950s]], the company was a member of the [[Ford Friction Team]].  The company was called the &quot;Shaft Grapek&quot; by the French satellite written by Alfred Belzec&amp;mdash;and was the first company to record several articles on both sides of the transcript.  In [[1961]], the company sold off $10 million in touch shows in [[California]], but the record was recorded in [[1964]].  The company announced that the company had converted $150,000 from $130,000 in compensation to multiple product
# ---------- 5.17s ------------------------------
# In the last years of the 20th century, diamond cutting and shortage of characteristics has created more attention for [[entertainment]]. The more popular cut was [[grindcore]] with a sophisticated television set, ''[[Selmasongs]]''. It is notable for being the largest diamond mixer that is now available from a [[short to his Latin not-for major girl disappearance|native martial artists]].
#
# == Controversy ==
#
# The debate over the differences between the two movements has also been the subject of contro
# ---------- 4.97s ------------------------------
# In the case of [[Arabic language|Arabic]], the term ''India'' can also be used as a synonym of ''[[Indo-Arabic canon]]'' as a [[proper noun]], as a [[suffix]] when it is used to represent the [[Greek language|Greek]] ''[[Manding (family)|mand]]''.
# * In the [[Hindi language]], '''''-in''''' has the suffix ''-inna'' as a foreign name, the suffix -''-sa-''', or the suffix -''-inna'', is used for suffixes e.g. {{IPA|/aj/}} or {{IPA|/aj/}} &quot;I have counted as ''ba''&quot;. Also see [[Indofara]].
# * In [
# ---------- 5.21s ------------------------------
# In the [[United States]], the survey is concerned with the development of a manual language. It is in the area that geographic distribution of a state is the established contract, and as a result itself is not a member of the [[supercomputer]].
#
# Each subclass of the subclass is of the following:
# *The subclass = Entropy
# *It ingots capacity to determine the substance properties
# *Entropy itself
# *Entropy itself
# *Entropy itself
# *Entropy itself
# *Entropy or [[Langley exponent]]
# *In thermodynamics and S
# ---------- 4.9s ------------------------------
# In the [[1800s]], the [[United States]] gave the [[International Standard Book Directive|ISDB]] standard for ISDB, which was adopted by the U.S. government. The [[International Standards Board of Consumers]] (ISC) was retained in [[1910]] and sold in 1903 by the [[International Olympic Committee|IOC]] (International Organization) for monthly editions.
#
# [[Image:ISDN logo.png|right|ISDN logo]]
#
# * The '''[[International Standard Audit Cache]]''' in [[Greenwich, Los Angeles, California|GIA]] International
# ---------- 5.26s ------------------------------
# In the [[United Kingdom]], [[Great Britain]], [[France]] and [[Germany]] Britain has had a major effect on the recent international spectrum of [[Northern Europe]]. At the same time, [[Johann Bennet]] became the first person to combine [[mobile telephone]] networks with major company ownership across the continent. Britain workers came up wisdoming this to develop its remarkable potential for foreign transactions and technologies for British transitional aging ([[caterpillar]]s and [[mineral]]s).
#
# Th
# ---------- 4.94s ------------------------------
# In the 1989 [[Anita Hill]] schedule for the sport of baseball played at the [[Property Manufacturers Association]] of Ancillary Magistracy in the early 1990s. It was returned to the [[World Trade Center bridge]] in [[1991]] and has since become a company economic activity.
#
# == Technology ==
# * [[Brass industry stadium]]
# * [[Brass industry sᑐ000 (Grand Fork)]]
# * [[Brass industry building]]
# * [[Brass make-user]]
# * [[Central branch Services]]
#
# == See also ==
# * [[List of brands of brands]]
#
#
# {{commons|Bras
# ---------- 4.89s ------------------------------
# In the 1960s and 1970s many people were able to study the literature in their direct quotations of the process of [[literature]]. A new apprenticeship was transformed into the [[American Broadcasting Company|ABC]] in 1968. The literary age from 1970 to 1982 had been replaced by the [[National Book Company]], which continues to insist on the use of literature and companies. The [[Chicago Board of Trade]] (CBC) received a commission as an executive organization for an independent state, which served as
# ---------- 5.2s ------------------------------
# In the United States, the major dialects of the United States are [[English language|English]] and [[German language|German]]. The principal languages of the world are [[English language|English]] and [[French language|French]], with its descendants being members of the [[Commonwealth of Nations]]. The distinction between Commonwealth and Commonwealth speakers is disputed. See [[American sport|American sports]].ֹloas, which is the only one of the most commonly considered english dialects.
#
# ===Commonwe
# ---------- 4.93s ------------------------------
# In the last few years a market economy was established to stimulate the process of common investment in [[hydroelectricity]]. The market was an essential factor in the economy's improvements and economic stabi余operia have also suffered from a consequent rise in the legalization of crops and what is today minority population.
#
# While the population declined further during the early 1950s, and the economy has gradually booed much of the country's population and continues to be so dependent on foreign ass
# ---------- 5.14s ------------------------------
# In the [[United Kingdom]], [[Anglo-American]] society was regarded as a modern conservative example of this state. The state of [[Georgia (U.S. state)|Georgia]] was created as a continuum under the [[regulation]] of [[1939]] and rejected the [[American Civil Rights Movement]]. It was also the basis of the [[Controversy]] that theӊievents were forced to compete in [[President of the United States|Presidents]] in 1940. In 1949 the [[President of the United States]] rejected the unrest of Congress, and w
# ---------- 5.0s ------------------------------
# In the end it has been included as a component of the complexity of a programming language. A set of simple and adaptating [[algorithm]]s is often more relevant than [[design]]ed to be more restricted. See also [[design cost]] and the support of the application.
#
# == History ==
# In [[Elliptical model|elementary school]] in [[1882]], the first [[science]]s used the term &quot;historical&quot; to refer to [[middle chord]]s (the [[articulation (system of language)|articulations]]), that had been developed
# ---------- 5.01s ------------------------------
# In the second episode of [[Peter Shell]]'s ''[[Alien (film)|Alien]]-breaking set in the 1960s'' the aliens of the trans-combatable cosmic progenitor, played a crucial role in the development of creationism.  The scientific evidence indicates that the scientific study of creationism was in frequent places where creationists are believed to have been familiar with the origins of the scientific society.
#
# == Bibliography ==
#
# === Cosmology ===
# {{Main|Cosmological creationism}}
# [[Image:Global Creation Scien
# ---------- 5.35s ------------------------------
# In the 1990s, the technology industry grew worse and started to decline with the production of the [[Manhattan Project]]. [[Manhattan Project]] in 1998 showed that the original intent of the manhpaww manhwar is that the live expert in language is considered an integral part of the integrated accessory in the [[United Kingdom|UK]].
#
# In the early 1980s, the [[East Coast Manhattan]] system was designed to provide the higher manhated integration of integrated circuits with many of the high increases in ci
# ---------- 5.19s ------------------------------
# In the mid-1970s, in part because of the introduction of the [[Reconnaissance power]] communications system in [[North Africa]], [[East Africa]], [[South Africa]], and the [[Asia]]n [[Rocket Commission]] were being assigned to the commercial centre to provide an alternative access for [[mobile phone]]s. In the [[United Kingdom]], commercial products have been in use throughout the world, with the former being the most popular.
#
# The airline is often called the ''[[Termination Nest]]'', which is also a
# ---------- 5.32s ------------------------------
# In the USA, the '''battleship''' was the term with a series of triggercouncils which would be called as '''battleships'''. They were also known as the '''battleship (and their like origin'''). They also had several types of battlecruiser ships, and the ships were usually designated as ''battleships''. They were considered as a separate battleship and are often known as ''battleships''. They were often referred to as ''battleships'', although maritime battleships were also known as ''battlechiefs''. Th
# ---------- 5.17s ------------------------------
# In the 1980s, [[American Football]] preferred the players' spell to playing the same dividend, the following year in the AFC Central.  In 1994, the AFC went with new president Tony Austin and was approached by [[Tom Macobsom]] in an election for the first strongest premiership game in a row.  With a 1-1 lead in total scandals, the press Red Sox won the penulous 12-4C awards, and started the first playoff game in 1997.  After the defeat, AFC North again revealed that a fourth place test was in the 1989
# ---------- 5.27s ------------------------------
# In the [[1970s]], the American composer [[Stephen Bethwell]] and his wife [[Sandra Bellfish]] were being invented.  American [[film producer|producer]] [[Bill Atkinson]] coined the term ''epistemology'' for an acting cinema movie, which in turn became ''epistemology'' and was a standard filmmaker.  He began to appear in the [[anime]] ''[[The Show Must Be His Shoulders]]'', where he first appeared in ''[[For Your Eyes before Christmas]]''. He was subsequently married to [[Linda Lovelace]] who self-perp
# ---------- 5.28s ------------------------------
# In the [[Balkans]], where it is known as '''''chirality''''' or '''''chirality''''', it can also refer to a [[society]] in which the social [[social class]] or [[construction]] of a [[community]] is described by the state as a [[patriarch]] of the government, often of the [[constitution]].
#
# == Chirality and martial ==
# A chiral chiral is a political system with a single constituent political system.  Although it is often said that it is not the same as in [[analytic philosophy]], chiral and will be o
# ---------- 5.2s ------------------------------
# In the mid-1990s, [[Martin Brano]] and [[Robert McCosham]] started their double-block rating of 256 by 20 by 512. The original was the ranking; the company had 165,292 supporting businesses, which had 176 operating models and around 120,000 brands in 1997. The sale of double the gross stamp machine to the first with 20% of the dollar's preference value in the first two by 1970. The government announced that it had earned $9 billion in backing value from $55 billion in 1999, down from $2.5 billion in 1
# ---------- 5.3s ------------------------------
# In the first half of the 19th century, and in particular the [[Allemania]]n government, in [[Belgium]] the [[International statistical exchange rate]]s for the statistics which still survive today. As a result of the disagreement with the governments of the United States and some states, it has been said that the statistical study of the [[International Statistical Classification of Diseases and Related Health Problems]] (ICDP) provides for the treatment of these claims.
#
# [[Expert witness]] and [[ant
# ---------- 5.06s ------------------------------
# In the [[American Civil War]], the Union sought to end the war and the relations with [[African Americans]] in the region. The Union also included in the [[American Civil War]], the [[Confederate States of America|Confederacy]], [[Allies of World War I|Allied]] and the [[Soviet Union]].
#
# In [[August]] [[1907]], Confederate and Union officials announced the [[Eisenhower enamegalor תronski]], or &quot;Ensign of the Confederate States&quot;. Although the Union was clearly a historical example, the state
# ---------- 5.16s ------------------------------
# In the United States, development of such titles was conceived in [[Philadelphia]] in [[Philadelphia]], [[United States]]. The company had a large interest in the [[stock market]], and a few of its major industry prospects were consolidated in the [[White House]]. [[Second Bank of the United States|Second Bank]] of the [[World Bank]] had never actually relocated into a more economical concept and continued to rely on a set of competing government employees who considered the banks' money.
#
# The privat
# ---------- 5.14s ------------------------------
# In the [[United States]], couples are selected from the political and military and community coupled.  In [[South Australia]], the [[British government]] can be regarded as the most powerful of these organizations and contributed to the [[European Court of Human Rights]] and the [[European Court of Human Rights]].  In addition, the [[United Kingdom]] can be described as &quot;a nation which has a relatively high powers over the interests of the parties.&quot;
#
# The term &quot;country禁]]&quot; is often
# ---------- 4.98s ------------------------------
# In the first place, the country is surrounded by the [[Great Lakes (Africa)|Great Lakes]] to the northwest and the [[Canary Islands]] to the east.  The largest of these remains is the [[Strait of Malacca|Malacca]] path.  Its industrial outputs were declining between 15,000 and 1500 miles (380 km).  The [[American Regional Hotels Association]] and the [[University of Texas at Austin]] have started to refurbisherable foreign research including the financial services of the [[American Red Cross]] and the
# ---------- 5.17s ------------------------------
# In the early [[1980s]], the [[Internet]] and the [[Internet]] adopted the idea of &quot;signing the [[Signal_module|signal]] for a signal from a [[frequency response]] of the signal which suggested that it could also be the cause of the possibility of the control of the particle in the cause of a continuous signal.&quot; [http://www.elasmo-research.org/education/theory/relativity.htm]
#
# The [[Caltech]] science fiction figure [[Part 2]] suggests that the contradictions between the signals on the interna
# ---------- 5.06s ------------------------------
# In the [[United Kingdom]] and [[Ireland]] it is a member of the [[European Union]], the [[European Union]] and its [[European Union]].
#
# ==Origins==
# [[Image:Easles-of-northern_rock_flare.jpg|right|thumb|250px|The Eastern European stereotype was a tradition in [[North America]] for the [[American Red Cross]] designed by [[Richard Nixon]].]]
# In the [[United Kingdom]], where the name &quot;[[Elizabeth I]]&quot; came to be synonymously interpreted as '''Elizabeth I''' (''Eli are born out of Heaven''), the
# ---------- 5.26s ------------------------------
# In the spring of 1962, [[John Donne]] and [[Robert Calvert]] published their article ''[[Books of the Bible]]''. The book of ''Book of Common Prayer'' was actually considered a religious text on the basis of the ''Book of Common Prayer'' in the second half of the 19th century. It was the book of most of the stories of the [[Scottish Bible]] and its subsequent published sources.
#
# ==Historical references==
# Books proclaimed in the last period of the conflict are centuries of prayer and scroll the traditi
# ---------- 5.01s ------------------------------
# In the first months of the day, several conservative groups had declared that the term &quot;grave quarter&quot; applied to the right of the president of the United States be protected by the constitution.  Since the Supreme Court could not have been the majority, a democratic group may be impeached or violated, and so granted a statutory compensation and consent of the same ground.  The Supreme Court will sometimes refer to the trial as &quot;the detention mark, &quot;the present Grand Lodge of Engla
# ---------- 4.86s ------------------------------
# In the early 1980s, [[John Pope (military scientist)|John Pope]] developed a more useful and sparsely-inspired design and created the [[Earth Liberation Front]] (ELF) after the 1982 release of the [[American Cold War Establishment]] (ECA).  The ELF lacked the need to stop it from taking on trials and brought the ELF along with its relatively new community and a certain severe constraint that was prevented from developing a planned economy through public authority and reducing its own monetary policy.
#
# ---------- 5.16s ------------------------------
# In the 1970s, the first concept of an insecure [[insect]] made from the extinction of the former in consequence of its r̟ [[cat]] and [[miller]] [[mushroom]]s (see [[catch-all curlers]]). In 1991, an entry for the [[toxin]] was used to insert insects, the plant and the first first currently buried in the [[plant mutation]]. This symbioses the [[muscle]]s and the [[spinal cord]] to the [[cytosol]] of the cell, thereby reverting to existing [[cell (biology)|cell]]s. The [[cell nucleus|nucleus]] of the [
# ---------- 4.95s ------------------------------
# In the meantime, most boys are a [[cannibal]] version of the boy for several years. The boy is described as having a &quot;boy&quot; in the casket, the player who is dependent on the boy as the boy has the pot. All the boys are dependent on the boy when a boy has female boy at the same time being a boy. A boy beyond a boy boy will be awarded a boy by a prince (the mother of Henry, and a boy who has been boyesized at the time) as the boy whose boy is saved from boy boy boy with such power it would be s
# ---------- 5.27s ------------------------------
# In the [[1996]] election, [[Eric Rasmussen]] appointed the President of the Republic and of the Prosecutor in the UN Election.
#
# In [[2003]], following semi-domestic violence against Saddam Hussein under the [[Israeli security forces]], Saddam Hussein announced that he would be peaceful and confident, and that his security clearance would result in more of the ongoing defeat and relapse of his communist government.
#
# ===Recent history===
# ===Early 20&lt;sup&gt;th&lt;/sup&gt; century===
# The [[President
# ---------- 4.97s ------------------------------
# In the meantime, the '''convention''' of [[the Enlightenment]] was coined by [[Paul de Man]] (or [[17th century]]) to teach the theory that the Enlightenment was understandable and that the [[Christianity|Christian]] conviction that [[Aristotle]] was the original Enlightenment and that it was the only suitable third party to be religiously in the world. In other words, there is no real understanding of the ability to prove the existence of [[analogy]].
#
# The [[philosophy of religion]] is sometimes cal
# ---------- 5.15s ------------------------------
# In the last two decades the canon is contemprated in several parts of the world, including [[Spain]], the [[United Kingdom]], [[Portugal]], [[Portugal]], [[Spain]], [[Sweden]], [[Switzerland]] and the [[United States]].
#
# In the 18th century, a constitutional amendment was signed by a constitutional amendment to the constitutionality of a political process under parliamentary system, by the [[Constitution of the French|French Constitution]]. The term of the constitution in the French Constitution can
# ---------- 5.23s ------------------------------
# In the same way that some sources would see ''The Thermal Constituents of Julia Van Dyck'' (1990), [[Ronald Fisher]] and [[Joseph Priestley]] put forward a theory that appeared to be sought in a single theory of the real world to compare the new theory to the ideas of the study of [[Free wills|free worlds]].
#
# The sociological argument that a source source ''a previously unrelated problem fits Change therist'' was not defined and was not the ''privilegia'' of ''private property'' (''private''), but rat
# ---------- 5.1s ------------------------------
# In the 1960s the [[European Community]] was invaded by [[Israel]] and into its [[Soviet Union]]. The [[United States]] continued a move towards discussing the creation of a communist society in Israel and supported the [[Republic of Ireland]] for fifty-four decades. The communists intervened to dominate the political process, the [[social democratic]] rule of thus pursuing a directed coup.
#
# ==External links==
# * [http://www.ericdigests.org/1995-1/marxism.htm Eric Voegel: A Study of Eric Voegel]
# * [http
# ---------- 5.27s ------------------------------
# In the 1980s some [[psychiatrist]] researchers such as [[Robert Woodrow Wilson]] and [[Douglas Engelbart]] announced the process of explaining series not entirely to experimentation.  The entire track was observed by [[David Macaway]] and was influenced by [[Max Beckmann]] and his work on [[the Edge]].  In 1990 they started experimenting with the subject matter of a combination of [[surfing]], [[terrane]] [[shopping]] and [[transport]] and the tendency of [[tea]] to make a special status of a permanen
# ---------- 5.04s ------------------------------
# In the [[2004 Summer Olympics]] in [[Eurovision Song Contest In 2002|2002]], [[Arsenal F.C.|Arsenal]] was the song that began a serious album album called ''[[Ars Politika]]''. It is the first true song on the pop single &quot;Arsenal In the Game&quot;, where it was the tenth time we forever reach some of its charts. Arsenal also had the lead singles from [[Middle Arsenic]] and [[Chicago Reagan|Chicago]]. Arsenal also had an all-time high-officer home run by [[John Brown (footballer)|John Brown]], but
# ---------- 5.14s ------------------------------
# In the last five months the political leaders of [[Cordoba, Spain|Cordoba]] and [[Alexander II of Spain|Alexandra II]] became presidents with the new constitution that the Consuls were merely ordered by the officers themselves (and not to the people of the Consulate General Exponus) in order to prevent invaders. The Consuls finally conquered Spain and Argentina in [[1833]], but the Spanish continued to experiment with consular arrangements and married poets and philosophers. The first was a catalogue
# ---------- 5.2s ------------------------------
# In the case of such a thing is the possibility that it is the more the ones that are not all related.  It is the set of all final positive integers.  This is called the '''[[product (category theory)|product]]''' of the product of the finite sets that are not continuous as the point is applied to the [[categoryA theorem]].
#
# === Proof ===
#
# If the product of the product of the product of the product ''y'' is ''finitely'' either ''x'' equal to ''y'' in the product of the product ''y''&amp;nbsp;=&amp;nbsp
# ---------- 4.92s ------------------------------
# In the press, in [[1999]] a constitutional amendment for the constitution of 1999 was stated to be the [[Australian Constitutional Court of International Jihad.]] The treaty was accepted as the proposed extension of the Court until [[1997]], which has been revised to protect the [[International Court of Justice]] in 2001.
#
# ==Examples==
#
# * [[Al Gore]]
# * [[Al Gore presidential campaign of 1997]]
# * [[Democratic Party (United States)|Democratic Party]]
# * [[Canadian federal election, 2001|Canada's parliame
# ---------- 5.13s ------------------------------
# In the [[1990s]], the proposed [[Arabic alphabet]] replaced the [[Egyptian Arabic]] record as the standard of words in the [[Arabic alphabet]].  The articles of the [[alphabet]] were added in the [[1990s]], as they were written by professional astronomers such as [[Phoenician]] and [[Arab]] colonizers in the middle of the [[12th century]]. The arrival of [[Marwan chandra$]] ([[1788]]) caused a considerable discussion of the maps the [[solar eclipse]] could not be read, and so arranged by a particular
# ---------- 4.98s ------------------------------
# In the 1970s, scientists stated that the idea of &quot;[[physics]]&quot; would have been consistent with an ideal wave of mass production that could be studied. Several theories have been proposed over the years, such as in a recent part of the [[1980s]] and [[1990s]], the [[University of California, Berkeley]] students such as [[Richard J. Daddington]], [[John Coates]] and [[Carl A. Dixon]], and [[John Barnes (magician) | John Barnes]].  [[Michael Spinder]], the first intelligent design magician, has
# ---------- 5.35s ------------------------------
# In the present context, any type of [[artificial neural network]] is used to separate the artificial arteries into the [[temporal lobe |group theories]] of the arteries. The arteries in a protein are made up of [[arterial space]]s (one protein and the other arteries) and the other arteries (the arteries and arteries around the [[corticospinal tract]]). The cortex has a high change in symbiotic immunity and therefore has no arterial success as a spiritual lifestyle.
#
# The arteries are typically sensiti
# ---------- 5.1s ------------------------------
# In the early third century, the [[Ancient Greece|Greek]] city-states of [[Athens]] and [[Thessaly]] were displaced or are still commonly used in the [[Roman empire]].  Although several [[stane|standard]]s (ca. 145&amp;ndash;170) were codified as early as the [[4th century BC]], the Athenians considered them to be essentially all attempts at their status. The [[Ars Mál]] (1608-1624) also referred to the Al-Andalro as the &quot;Caliphate of civilisation.&quot; The Athenian Empire was founded by the Arab
# ---------- 4.97s ------------------------------
# In the [[1960s]], [[Rick Rushdaer]] and [[Steve Vai]] were the first professional professionals at the time. Rush sponsored at [[University of Dewan|Dewan University]] in [[1971]]. Rushdie [[Peter Gammon]] was the producer of the ''Rush'' in the [[1970s]] and served the second highest amount of his professional career. He also became the sole professor of engineering at the [[University of Texas at Austin]] and the school of [[London University]]. He continued to study the search for professors before
# ---------- 5.23s ------------------------------
# In the first chapter, the letters are added to the [[Latin language|Latin]] ''auteur''. The correct way to describe the chapter is &quot;a tint is to say that the author must be a priest at the end.&quot;  In the United States [[National Academy of Sciences]], the [[University of Toronto]] was also called &quot;the first great corporation&quot; by the British motorist [[Henry Laurens]].  In his autobiography &quot;I was a free man&quot; he states that a series of former senators had to keep the senior
# ---------- 4.81s ------------------------------
# In the 2003 [[Max Morrison]] version of the story, [[Sam Raimi]] was able to assume the speed of the crew was stronger than the more distant city of London (which the train stayed for), and subsequently he would probably start busy the space and better with the spaceship than the transport system. He was then returned to France with a loss of note, and was completely destroyed in July 2005.
#
# == State Archives ==
# He is the only channel to withheld press conferences on the following [[television]] broa
# ---------- 5.2s ------------------------------
# In the middle of [[summer]], the [[Independence of Bangladesh]] was one of the most popular trading independent against the country.  The [[Arab World]] considered the birth of the ''Independence Day'' to be the most popular of the seven nations at that time, as it was done by [[Turkey]] or by [[Canada]].
#
# The '''Independence Day''' ('''IDE''') is the time to display before and after the date of its [[Food and Drug Administration| defined]] to be calculated for the time being a matter of sacrificing
# ---------- 5.11s ------------------------------
# In the 1980s, the company successfully repackaged the new design based internally. The initial sales of the new platform included a selling arm of $2,98g/long duration (20 minutes) of computer code on the new network, and a new company such as [[Boeing]]'s [[GNU]] console, [[Sony]]. The new [[IBM PC]] was later renamed the [[GNU Project]] by [[Tim Berners-Lee]].
#
# The new company was bought by [[GNU Compiler Collection|GCC]], and was originally released as the [[GNU General Public License|GCL]] in [[20
# ---------- 4.98s ------------------------------
# In the case of [[artificial intelligence]] it is clear that the intelligence within a system will always consider the effects of the distinction between the sensory input and the effects of the external intelligences.  A particular factor to which the intelligence of the forces will be in place by security concerns is that the intelligence of the intelligence will continue to contribute to the intelligence of the intelligenceia performers.
#
# ===Software===
# The intelligence service depicted on the intel
# ---------- 5.22s ------------------------------
# In the [[United States]], an elected government has trained in the [[United States House of Representatives]] to consider the profession of a minister who has received a parliamentary election shortly thereafter.  The most notable electoral shifts in the presidential council are the election of the [[Chief Executive of Hon. Louis Fourtug, 2nd Earl of Houston|Lord Houston]], the leader of the President of the United States, and the remaining three U.S. presidents. The U.S. Congress retains most of the
# ---------- 5.1s ------------------------------
# In the summer of 1989, the Caribbean Islands were occupied by the United States and Canada that made its lack of support not traditionally existing occupations throughout the country. The population increased frequently, and in 1990 the islands received the largest number of [[Caribbean]] island chains which included a net increase of 2,382 people, and a total of 2,096 changes during the confluency of the Caribbean Sea had been about 5 million inhabitants (1991).  At the same time, the country grew et
# ---------- 5.34s ------------------------------
# In the [[1930s]], the [[American Civil War]] and the [[Continental Army]] were able to prevent [[Confederate States of America|Confederacy]] and the [[Army of Northern Virginia]]. In [[1936]], [[George Hamilton]] created the [[Confederate Army of Tennessee]] (now called the '''American Army''') by suppressing the [[Army of Northern Virginia]] on the platters of [[Joseph Smith, Jr.]] and [[Confederate Serbia from Iran|Confederate officiated in Virginia]]. A [[Battle of Fort Sumter]] ([[North Carolina]]
# ---------- 4.97s ------------------------------
# In the 1980s, Carl and Henry Robinson, [[Edwin Albert Studiros]], became the first women to sign the treatment of marijuana. Studies indicated that they had no significant effect upon its surroundings, which included [[Richard Stallman]] and [[Richard Perle]]. Also, the [[Eugenics Record Service]] was the first successful person to conceive of itself as the original trait. The transition was intended to be the foundation of the transition from one generation to another by the second generation, [[Tran
# ---------- 5.13s ------------------------------
# In the USA the [[South Korean Army]] officially recognized and responded by accusing the Japanese troops of communist targets.  Some argue that the Japanese police force represented a prolonged recession in the [[Soviet Union]].  The reports of the Japanese police forces had little effect on the atmosphere of the Communists and the threat of communism was put into initiative by the secedings to support the Soviet arms communist party in the [[Marshall Plan]].  The USSR came to power in the early [[198
# ---------- 5.2s ------------------------------
# In the early 1950s, [[Germany]] and [[England]] formally broke away from the authorities and for six months until the attacks of [[Roman Catholic]] and [[Jew|Jewish]] [[heresy]] in 1956. At the end of the 1950s the German school of labour and social developments developed in the region and for several centuries, the most developed was the [[Roman Catholic Church]] which became known as the [[Eastern Orthodox Church]]. The schism in 1955 started in the late 1970s, and the first Eastern Catholic Churche
# ---------- 5.09s ------------------------------
# In the 1970s, he was already the first woman elected at the [[University of Paris]] to become a member of the [[Democratic University of Chemistry]]. He was the son of a character of the Beretta School in [[Paris, France]] and [[Dale Bruno, Barone]], who attended the funeral in Leipzig at [[Kabul University]] in [[Paris]].
#
# The next year he began to publish a work at the Berlin Bible College in [[Paris]]. In 1875 he published his bell ''Alec,0+: Concertos, other Biblical Amorites and Other Deities'',
# ---------- 5.37s ------------------------------
# In the past, and indeed the country of Danube in the north, the area was recognized by Balkh as the capital of the newly independent nation of [[Balkh]].
#
# == Danish cities ==
# {{main|Dan’s No. 1}}
# Dan’s population in the north of Danish is generally good because of its small size, and some may support a饭nual [[fishing]]. In the north of Iceland, Danish is a [[national anthem]], with a large number of native people and cultures dedicated to the national territory of Danish national and localities. The
# ---------- 4.98s ------------------------------
# In the 1980s and 1990s a much more acceptable learning program that managed to develop software which would contribute to the new revenue system. All of these applications were accepted as the first practical computing projects in the world. A new approach was to create a [[Mac OS X v10.4]] and manage the server management of [[Windows 98]]. The management was designed to support the use of peripheral machines with control structures. The second appeared in the mid 1990s and through Chinese applicatio
# ---------- 5.27s ------------------------------
# In the [[United States]], the word &quot;college&quot; is often used as a synonym of [[College of Cardinals|College of College Basic]] in a local sense that is necessarily a teaching position for independent students. The term college is derived from the word ''college'' for the first time, but is also used for schools and the [[College of Colu؟]].
#
# Most colleges have a street plan of address at the high-school grammar school, but the college still extends from within the city's [[Michigan State Unive
# ---------- 5.08s ------------------------------
# ...
# ---------- 5.45s ------------------------------
# In the meantime in [[2001]], it became considerably more impressive than the modern revived [[Daniel Karrier-Bremen]] ([[2001]]&amp;ndash;present). In the mid-[[20th century]], the characteristic in an [[Erd&amp;#337;s]] farm was in [[Switzerland]], the farmer came to little with [[Margaret Thatcher]]. The largest software engine of the 20th century was [[Commodore (rank)|Commodore]]. The largest modern development event was the [[2004]] [[Bremer (DDR-2)|Bremer]] rating.
#
# == External links ==
# {{wikine
# ---------- 5.23s ------------------------------
# In the [[1800s]], [[Mike Judge]] and [[Andrew Westenberg]] discovered the choice of manners.  Western [[London]] and [[West End]] the [[Middle Ages]] began to reduce the chance of the reliability of the transition.  The [[Middle Ages]] in the early [[1800s]] were divided between the main characters of the characters' manuscripts and the subject matter of the [[Renaissance]].  The distinctive version of the story was the personal art which reached the time of the [[First Visit of Ireland|First Visit]]
# ---------- 5.44s ------------------------------
# In the [[1800s]] [[Charles Lyell]] founded [[France]] in [[1805]] to merge [[Calvinism]] in [[1809]]. He is a [[Freemason]], and is one of the few parts of his thought at the time that is widely known. He is sometimes known as the &quot;Free Doctor&quot; and also as premier of the early 19th century. He was the first [[Germany|German]] [[political science|political scientist]] or [[Franz Bopp]]. He is considered by many to be the founder of the [[Freemasonry|Freemasonic lodge party]] and at the [[Univ
# ---------- 5.33s ------------------------------
# In the past, Canada has received nearly two national ports: [[Europe]] (which has been liberalized in [[Europe]] and the [[United States]] [[American Civil Liberties Union|ACLU]]), [[New Deal]] (where the region has never been able to control the continental railway) and [[Burkina Faso]]. In 2005 the former [[Railways Act 1988]] has a lower liberalization problem that is now done at the top of the business rather than being raised in the percentage of the national railway company ([[Rail Breaches Agre
# ---------- 5.52s ------------------------------
# In the case of the [[Church of England]], a number of more than half of the church in the world have returned as early as 100 years or to the present.  However, many communities of Irish who are members of the Church of Ireland continue to serve in the English language and are still studying whether they are English-speaking or tribal languages.
#
# [[Scots language|Scots]] is also the second language for linguistic and historical communication, as it is also a language of advanced languages and language
# ---------- 5.36s ------------------------------
# In the end, the ''n''-ary expression delineated by the parent node can be replaced by a node ''n''-sign relating the segment to the bottom of the parent, and the parentheses ''n''-sign relationship can be expressed as:
#
# :&lt;math&gt;\sigma^2 = -nz&lt;/math&gt;
#
# and ''n''-sign n is a relation of ''n'' signs as the segmented sign and the first two signs are assigned.
#
# The array along is a powerful formal analog signal which can be recommended to the sign and used by a two-signature background.  The arr
# ---------- 5.33s ------------------------------
# In the 2003 French Federal Council (now legal to sympathize), the Spanish government had made excellent ÀTEAU with a strong dormant force in eastern Brazil. In the 1980s, [[Angola]] had lost its independence and re-organised war in Bolivia and the United States was defeated and replaced by the [[Montenegro Ranger|Russian National Resistance]] targets. The regime prompted troops to deliver perceived corruptions in the country, and the country continued to expand the government over time. Although the c
# ---------- 5.47s ------------------------------
# In the first three years of Canadian socialism in [[1909]], the [[French National Library]] published a privately published annotation service in [[London]] and another independent [[science fiction convention]] ''[[Canadian National Park]]''. The [[National Park Authority]] was founded in [[1901]].
#
# The [[States and territories of Australia|states and territories]] were established in [[1910]]. In [[1921]], the [[United States Department of Agriculture|United States Department of Agriculture]] was e
# ---------- 5.36s ------------------------------
# In the early [[1950s]], with the [[Ford Mustang]] introducing the first [[musical tonalis|continuo]] music for [[popular culture]], a film crew became the concert by all actors. The film also included [[Robert A. Heinlein]], [[Lee Remick]], [[Robert Michael Brown (song)|Michael Brown]], [[John Robert Sinnott]], [[Stephen Fry]], [[Chris Watson]], [[Charles Sherrino]], and [[Bob Spiers]].
#
# For a list of films, see [[List of movies that listed everyone else's film at: Christ Church]].
#
# [[Category:Christ
# ---------- 5.47s ------------------------------
# In the [[1980s]], some conservatives continued to take socialism increasingly as an elective retaliator, as elected by many to be a substitute for [[market economy|market economies]]. This led to the [[1984]] [[Paris Peace Party]] movement.
#
# ==Post-Soviet Conflict==
# {{main|Sovereignty of the Future}}
#
# [[Image:Chilean President.png|thumb|right|[[Vichy France]] disputed by the Greek military occupied the present-day Bahia with the title of his senator]]
#
# ==Crime==
# British authorities in the area of the
# ---------- 5.46s ------------------------------
# In the 20th century, international media writer [[Richard J. Daley]] used the term to describe the changes in the distribution of computer technology and the development of computers.  The design of the computer could be used to avoid any confusion made by the computer markets in general thought and by the process of the design of the disk drives.  This interpretation is also applied to design concepts in the same design as the [[computer model|computer model]] architecture.
#
# As an instruction code,
# ---------- 5.43s ------------------------------
# In the late 1980s, a move towards its new research determined that the relative lack of physical acceptability of chemotherapy and compulsiving the body can be considered the most commonly used chemotherapy chemotherapy characteristic of the therapy. The启rapadhar = cureth reproductiveas chemoth. Journal of Sun TSN, Teenagep, Savier-Sütah Issan (Torah Chemie) contaminated the reproductive system of chemotherapy and reproductive East India Production. Some studies have produced this treatment.
#
# == Exter
# ---------- 5.4s ------------------------------
# In the more extreme examples, extreme solutions of extra solutions are available to convert a [[control sign]] or both. This means that the value of a control signal is not always easily prevented. For example, the &quot;next signal&quot; power on a physical site (which in turn represents a position of the output of the signal, in which the three power signals are powered by the output of the output, and the output from the output signal is the [[frequency modulation|FM]] signal.  This can be done in
# ---------- 5.32s ------------------------------
# In the United States, an international organization may send the country to seek a foreign trade by concerning commercial enterprises. The sole exceptefore is the [[International Monetary Fund]], which consists of four state instated residents of the US, as opposed to the US controlling the country as the country enjoys, though the US and European Union has been characterised by controversial benefits such as promoting a common international organization or other institutional institutions.
#
# The count
# ---------- 5.49s ------------------------------
# In the early 1980s, some enterprise kinetoscopes were developed as the basis for som前reaching the sport into which the sport had been played with, by the end of the early 2000's, into 및
# [[image:alabama_railroad.jpg|thumb|right|The original ''Alabama Railway'']]
#
# On [[November 18]], [[2005]], a [[satellite channel]] was presented in the [[United States Grand Prix]]. In the [[2005 El Auburn summit]], [[Raymond Elizabeth Montres]] published a series of contact scores of the same sport which have produce
# ---------- 5.47s ------------------------------
# In the first series, since a series of relatively new films there are some devices for producing production records.  In this respect the film has a distinctive marketing ability in the United States to be used as a source of controversy.  The audience may offer a fair amount of detail in their productions and income, and in fact the film is still mainly seen by the company's company of consultants.
#
# The audience often chose the same characteristics, even when a character involved worker arrangement
# ---------- 5.45s ------------------------------
# In the [[2003 invasion of Iraq]], [[Al-Qaeda]] was the largest and most prominent of the major self exports. A [[F-16]] - [[F-16]] fighter vehicle, the [[F-16]], first played in [[South Korea]], has sold over 250,000 trade persons in 1993-1999. The ground-plan is on the south side of the city, which has straddled the sector of the service industry in the middle of the night.  As of 2005, the second take on the near status of [[F-16]] has been established over the years.
#
# ==History==
# {{main|History of
# ---------- 5.37s ------------------------------
# In the 1990s, a new technology had been proposed, which was considered too much to provide a strong personal physical structure for the [[computer]] business and profit economy of such companies. The [[price controls]] over the company called [[Marketing]] were developed by [[Norman Cohen]] in 1985, which included the creation of [[Control Group]] which called for free trade and [[diversion]] of software and the first [[personal computer]] to commercialize and develop the proprietary [[CPU]] of the 19
# ---------- 5.46s ------------------------------
# In the popular programming language [[Distributed computing]], Distributed computing is an important application of the programming language.
#
# Distributed computing has been used by some [[creative computing]] organizations and in [[finance]] in the process of [[computer science]]. A [[computer system]] which is not superseded in the [[mainframe]] of [[computer game]]s is used to manage the system for some purposes, including [[computer security]], [[security]] and the [[computing]] layouts of [[softw
# ---------- 5.48s ------------------------------
# In the meantime the state has been entirely distinct from the state of the United States. The most significant political and cultural history of the United States was a treatment which in the United States was negotiated by the U.S. in 1922 as the American English Council of Europe (EC).
#
# [[Image:Greens.jpg|thumb|200px|The President Greens, who were listed on the U.S. Senate on [[2 February]] [[1922]].]]
#
# In [[1930]], [[Paul Tillich]], the leader of the [[Congress of the United States|U.S. Congress]]
# ---------- 5.34s ------------------------------
# In the post-war period, the [[Magyars]] used the regions to build a state called [[Great Magen magnitude|magnitate]], but allowed them to settle in the [[Baltic Sea]] in an era of invasions by [[World War I]]. The first permanent settlements were destroyed in a storm for a series of devastating explorations of the region in [[1921]] between the [[Baltic Sea|Baltic]] and [[Baltic Sea]] coastlines and in the southern [[Pradesh]]. The [[Saxons]] and [[Swedes]] were captured and conquered by [[Germany]] i
# ---------- 5.42s ------------------------------
# In the [[United Kingdom]], [[Ireland]], [[Scotland]] and [[Wales]] it is also possible to adapt the [[culture]] for each of the five main categories in the world, with its common definition of the term ''colony'' of ''[[nationality]]''.
#
# ===The first source===
# The first source is the [[colonialism|colonial]] controversy that started with the [[British Empire]] in the [[19th century]], and in the first overland period in the [[Middle Ages]]. The status of the colonial period is most often referred to i
# ---------- 5.41s ------------------------------
# In the late [[1980s]], [[Australia]] and [[New Zealand]] attempted to create a single large area of location at a late d angrily to streams areas of steep rainfall and leagues. Althou瑟 [[Great Hakkara]], like the [[New Rams]] football team, was converted to New Zealand. It was in the New Zealand version of the country, and speむto. The New Zealand football was part of the country for three years, the only for the ranking of a new NZ formation.
#
# In [[1995]], New Zealand claimed that it was the only foo
# ---------- 5.57s ------------------------------
# In the [[2001]] media scandal, the [[Southern Democratic Union of Germany]] (SDU) was founded by [[Rosa Luxemburg]] and the ''[[Rainbow Commons Christmas Clock Company]]''. The prime source of the first group to support the [[International Monetary Fund]] was created by the Soviet Union and supported by the supporting reform. It also helped re-establish control of marketshare for its oil and gas production and the establishment of the [[European Union]] and its manufacturing industries. The government
# ---------- 5.28s ------------------------------
# In the mid-1980s, the press began to discontinue another fraudulent paper (especially [[as of 2005]]) to prove that the constitution was a problem in calling it a [[constitution]] or [[separation of church and state]]. The church has been unable to actively consensual work for many years, and it is claimed by the public to seek it with the constitution that [[Pope Paul V]] saw in 12 countries ([http://canada.usda.gov/PrnewSkirner.html]) which discusses the rights of the provinces.
#
# In 2004, the [[Pres
# ---------- 5.35s ------------------------------
# In the 1970s, many people in the U.S. were also influenced by the U.S. and most refugees of the U.S. military.  [[Chinese American]] and [[Nakata language]] groups included a mix of [[African Americans]] and [[Spanish Americans]].  [[France|French]] and [[United Kingdom|British]] descent were marginalised by [[Portugal|Portuguese]] occupation there, and several other countries of the world were also the founders of continental [[Europe]].  After [[World War II]], the U.S. supported the growing popular
# ---------- 5.44s ------------------------------
# In the first three years of the first two decades of the 19th century, the greatest individual of all time was conceived in the house of an individual garnering military campaign against extremists and individuals as property to an individual who had been forced to accept the individual by himself and others. However, the monarchy also came to an end with the rise of [[France]] as a [[conservative]] group, and the [[military dictatorships]] of the [[Empire]] and [[Second World
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-7d42632e0b98> in <cell line: 81>()
#     106             out = copy.deepcopy(init_state.out)
#     107         else:
# --> 108             out = model.run(x)
#     109         if DEBUG_DEBUG:
#     110             print('model', np.array(x), '==>', np.array(
#
# <ipython-input-18-ebd20da67c85> in run(self, ctx)
#     115                 x = x + self.SA(x, w.blocks[i].att, f'att.{i}')
#     116             x = self.LN(x, w.blocks[i].ln2)
# --> 117             x = x + self.FF(x, w.blocks[i].ffn, f'ffn.{i}')
#     118
#     119         x = self.LN(x, w.ln_out)
#
# <ipython-input-18-ebd20da67c85> in FF(self, xx, w, name)
#      76
#      77         r = torch.sigmoid(w.receptance.weight @ x)
# ---> 78         k = torch.square(torch.relu(w.key.weight @ x))
#      79         kv = w.value.weight @ k
#      80
#
# KeyboardInterrupt:

# %% [markdown]
# 課題1
#
# RWKVはなぜ期待されているのか、自分の言葉で纏めなさい

# %% [markdown]
# 課題2
#
# その他、注目する技術は次々と登場している
#
# 何でもよいので、最新の機械学習に関連する技術について調査を行い、簡単に纏めなさい
